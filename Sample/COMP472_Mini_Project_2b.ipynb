# %% [markdown]
# # Imports

# %%
# IMPORTS
import copy
import numpy as np
from enum import Enum
import bisect 
import time

# %% [markdown]
# # CLASS INITIALIZATIONS

# %%
class Direction(Enum):
  HORIZONTAL = 1
  VERTICAL = 2

class Coordinate():
  def __init__(self, X, Y):
    self.X = X 
    self.Y = Y
  # Primarily for testing to see if Coordinate works
  def __str__(self):
    return "(" + str(self.X) + ", " + str(self.Y) + ")"

#
# CAR
# 

class Car(object):
  def __init__(self, letter, coordinate, fuel):
    self.letter = letter  # Remember that A is the most important
    self.coordinates = []
    self.coordinates.append(coordinate)
    self.fuel = int(fuel)

  def isA(self):
    return self.letter == 'A'

  def move(self, amt):
    if self.direction == Direction.HORIZONTAL:
      for c in self.coordinates:
        c.Y += amt
    else:
      for c in self.coordinates:
        c.X += amt
    self.fuel -= abs(amt)
  
  def canMove(self):
    return self.fuel > 0

  def compareLetters(self, letter):
    return self.letter == letter

  def addCoordinate(self, newCoord):
    self.coordinates.append(newCoord)
    # Update direction
    # L-R (Horizontal)
    if self.coordinates[0].X == newCoord.X and self.coordinates[0].Y != newCoord.Y:
      self.direction = Direction.HORIZONTAL
    # U-D (Vertical)
    else:
      self.direction = Direction.VERTICAL

  def getLetter(self):
    return self.letter; 

  # Primarily for testing to see if Car works
  def __str__(self):
    s = self.letter + " -> ";
    for i in self.coordinates:
      s += str(i)
    return s + " | " + str(self.fuel) + " | " + str(self.direction)

  @staticmethod
  def create(letter, coordinates, fuel):
    return Car(letter, coordinates, fuel)


#
# BOARD
# 

class Board(object):
  def __init__(self, cars):
    self.grid = [['.' for i in range(6)] for j in range(6)]
    self.size = {'X': 6, 'Y': 6}
    self.cars = []
    for car in cars:  
      c = car
      self.cars.append(copy.deepcopy(c));
      for coord in c.coordinates:
        self.grid[coord.X][coord.Y] = car.letter
        
  def __eq__(self, obj):
        return self.grid == obj.grid

  def findCarPaths(self, car):
    if car.canMove():
      fwd = self.checkPathForward(car)
      bwd = self.checkPathBackward(car)
      carPath = bwd + fwd
    else:
      carPath = []
    return carPath
  
  def moveCar(self, carLetter, amt):
    for car in self.cars: 
      if car.letter == carLetter:
        for coord in car.coordinates:
          #print(coord)
          self.grid[coord.X][coord.Y] = "."
        car.move(amt)
        for coord in car.coordinates:
          #print(coord)
          self.grid[coord.X][coord.Y] = carLetter

        # Is this a regular car that just left?
        if car.letter == self.grid[2][5] and car.direction == Direction.HORIZONTAL and car.letter != "A":
          for coord in car.coordinates:
            self.grid[coord.X][coord.Y] = "."
          self.cars.remove(car)  
         

  # ......
  # ...AA. (1,3)(1,4)
  # ......
  # startPoint = 4
  # range(5,6) -> 5
  # next gridPos = (1,5)
  # append -> 5 - 4 = 1

  # ...D.. (0,3)
  # ...D.. (1,3)
  # ......
  # startPoint = 1
  # range(2,6) -> 2, 3, 4, 5
  # next gridPos = (2,3)
  # append -> 2 - 1 = 1
  def checkPathForward(self, car):
    dir = car.direction
    lastCoord = car.coordinates[len(car.coordinates)-1]
    if dir == Direction.HORIZONTAL:
      startPoint = lastCoord.Y
    else:
      startPoint = lastCoord.X

    possibleMoves = []
    for i in range(startPoint+1, 6):
        #fuel req
      if(car.fuel < i-startPoint):
        continue;
      # Find next position to check    
      if dir == Direction.HORIZONTAL:
        gridPos = self.grid[lastCoord.X][i] 
      else:
        gridPos = self.grid[i][lastCoord.Y]

      # If there's an open position, add and continue
      # Else, there is something blocking the way and there's no way to continue any more
      if gridPos == ".":
        possibleMoves.append(i-startPoint)
      else:
        break;

    return possibleMoves

  # ......
  # ...AA. (1,3)(1,4)
  # ......
  # startPoint = 3
  # range(3,0,-1) -> 3, 2, 1
  # i = i - 1 -> 2, 1, 0
  # next gridPos = (1,2)
  # append -> 2 - 3 = -1

  # ...D.. (0,3)
  # ...D.. (1,3)
  # ......
  # startPoint = 0
  # range(0,0) -> NONE
  # next gridPos = NONE
  def checkPathBackward(self, car):
    dir = car.direction
    lastCoord = car.coordinates[0]
    if dir == Direction.HORIZONTAL:
      startPoint = lastCoord.Y
    else:
      startPoint = lastCoord.X

    possibleMoves = []
    for i in range(startPoint, 0, -1):
      if (car.fuel <= (startPoint-i)):
        continue
      # Find next position to check
      if dir == Direction.HORIZONTAL:
        gridPos = self.grid[lastCoord.X][i-1] 
      else:
        gridPos = self.grid[i-1][lastCoord.Y]

      # If there's an open position, add and continue
      # Else, there is something blocking the way and there's no way to continue any more
      if gridPos == ".":
        possibleMoves.append(i-startPoint-1)
      else:
        break;

    return possibleMoves

  def winConditionMet(self):
    if self.grid[2][5] == "A":
      return True      
    return False

  # Outputs
  def __str__(self): 
    s = ""
    for x in range(6):
      for y in range(6):
        s += self.grid[x][y]
      s += "\n"
      
    return s

  def stringLine(self):
    s = ""
    for x in range(6):
      for y in range(6):
        s += self.grid[x][y]
    return s

  def AllUsedCars(self):
    s = ""
    for c in cars:
      if(c.fuel < 100):
        s += c.getLetter + " " + c.fuel + " ";
    return s

  #Heuristic definitions:

  #h1 = The number of blocking vehicles
  def h1(self):
        count = 0
        last = " "
        for i in range(6):
            e = self.grid[2][5-i]
            if e == "A":
                break
            elif e == last:
                continue
            elif e != ".":
                count += 1
                last = e
        return count
  
  #h2 = The number of blocked positions
  def h2(self):
        count = 0
        for i in range(6):
            e = self.grid[2][5-i]
            if e == "A":
                break
            elif e != ".":
                count += 1
        return count
    
  #h3 = The number of blocking vehicles (h1) multiplied by a constant
  def h3(self, constant):
        return self.h1()*constant
    
  #h4 = Is there a car blocking the exit square (3f)
  #Yes: h4 = 1
  #No:  h4 = 0

  def h4(self):
        if self.grid[2][5] != "." and self.grid[2][5] != "A":
            return 1
        else:
            return 0

# %% [markdown]
# # Extracting Data From Sample-input.txt

# %%
demos = []
demoFuels = []

with open('sample-input-50.txt') as f:
    for line in f:
      if not line.startswith(('#', '\n')):
        in_arr = np.array([line.strip()])
        data = np.char.split(in_arr)[0]
        demos.append(data)
f.close()

print(demos)
# Out:
# [['Z.BOOOZ.B....AAC...D.C...DPPPE.....E'], ['....ZZ....O..AA.OB....OB.....C...DDC'], ['....Z.....Z.AA.BC..O.BC..ODDEE.O....'], ['..ZOOO..ZP.B.AAP.B...P.......C.....C'], ['ZZ..O...BBOC..AAOC...DD...EFF...E...'], ['...O.....O.Z.AAO.Z......B.C...B.CPPP'], ['.....Z..OOOZAA.B.C...B.C.DDPPP......'], ['ZOOO..Z.BC.DAABC.D..PPP.............'], ['ZZBBCC....DE..AADE..O.....OFGG..OF..'], ['ZZ.BCCOOOB.D..EAADFFEGGHIJJ..HI...KK'], ['...ZZ....BCCAA.B.D...E.D...EFF......'], ['OZBBCCOZ.DEEOAADF.GGH.FP..HIIP.JJKKP'], ['OZBCCDOZBEFDOAAEF....GHHII.G..JJPPP.'], ['Z.BOOOZ.BCDDPAACEFPG..EFPGQQQH.....H'], ['...OOO....P...AAP..QQQP...ZBCC..ZB..'], ['Z.O...Z.O...AAO..........BBC.DPPPC.D'], ['..OPPP..OZ.QAAOZBQ...RBQ.CCRD....RD.'], ['ZZ..O.BCDDOEBCAAOE.P.....PF.GG.PFQQQ'], ['..Z.BB..ZC...AACD.....D...E.FF..E...'], ['...OOO......AA.P..ZZ.PB..C.PB..C.QQQ'], ['..ZBCC..ZB....AADE....DE.FFOOO......'], ['.ZZ.BB...CC.AA.OD....OD....OEE......'], ['OOO.P...ZZP...AAP.......BBC.DD..C...'], ['ZBBCDDZ..CEEAA..O..PPPOF..G.OFHHG.II'], ['.ZZOOO.....BCC.AAB..P.....PQQQ..P...'], ['.ZZ..OBBPPPOQ.CAAOQ.C...Q..DEEFF.DGG'], ['...OZ...BOZ.AABOCD....CD........EE..'], ['...OOO....ZZBBPAAC..P..C..PQQQ......'], ['ZBB.C.Z.D.COAAD..O.PQEEO.PQFGG.PQFHH'], ['..O.....OPPPAAOQ.Z...Q.Z.BBQCC......'], ['Z.OOO.Z..BCCAA.BDP.QQQDP.E...P.EFFGG'], ['.......OOO.ZAAB.CZ.PB.C..PDD...P....'], ['Z.B.CCZ.B...AAD..EFFD..EOOO.GH....GH'], ['...O...ZZO.B.AAO.B..C.....CPPP..DD..'], ['..OZ....OZ.BAAOC.B...C.....DD..EE...'], ['..ZZOP.QQQOP.BAAOP.B.C.....CDD...RRR'], ['ZZOOO.....B...AAB...C.DD..C.EE.PPP..'], ['..OP....OP..AAOP....ZZ...B..C..BDDC.'], ['.OOOZZ...BC.AA.BC....PPP............'], ['..ZZO.....O.AA..OB.....BC.DDEEC.....'], ['..Z..O..Z..OAAB..O.CBPPPDC.EFFDGGE..'], ['Z..BCCZODB...ODAAE.OPPPEQQQ.FG....FG'], ['.ZZOOO....B.AA..B...CCDD...PPP......'], ['ZZBBCDOOOECD.AAE.F..G..F..GPPP....HH'], ['.ZZBCC...B....AAD.....D..OOOE.....E.'], ['.ZBBC..Z..C.AAD.O...D.O...E.O...E...'], ['....O.ZB..OCZBAAOC.DPEFF.DPE....P...'], ['OOO.PQ....PQ..AAPQ........ZRRR..ZBB.'], ['.ZZ.....BC..AABC...DD...............'], ['..O.ZZ..O.BBAAO..C.....C...DEE...D..']]

# %% [markdown]
# # Setting the boards up

# %%
boards = []
for data in demos:
  # Seperate Grid Data from the Fuel Parameters
  grid = data[0];
  fuels = []
  if len(data) > 1:
    fuels.append(data[1:])

  cars = []
  for row in range(6):
    for col in range(6):
      current = grid[row*6 + col];
      
      # If Unique: Create a car and append
      # If Not Unique: Concat to same letter
      if current == ".":
        continue

      unique = True
      for c in cars:
        if c.compareLetters(current):
          c.addCoordinate(Coordinate(row,col))
          unique = False

      if unique:
        # Now check if there's a unique fuel amount or if its the default 100
        fuelAmt = 100
        if len(fuels) > 0:
          for f in fuels[0]:
            if current == f[0]:
              fuelAmt = f[1:]

        cars.append(Car.create(current, Coordinate(row,col), fuelAmt));

  # Checking if all cars were made properly
  print("CARS: ")
  print("--------")
  for c in cars:
    print(c)
  print()
  
  board = Board(cars)
  # Checking if all boards were made properly
  print("BOARD: ")
  print("--------")
  print(board)
  print()

  boards.append(board)

# %% [markdown]
# # Building State Space Search - Uniform Cost Search (UCS)

# %%
class Node(object):
  def __init__(self, board, cost):
    self.board = board
    self.cost = cost
    self.path = []
    self.parent = 0
  def __lt__(self, other):
        return self.cost < other.cost
  def __eq__(self, other):
        return self.board == other.board
  
    
class UCS(object):
  def __init__(self):
    self.opened = []
    self.closed = []
    self.count = 0

  def recursivePrinting(self, node):
    if node.cost != 0:
      self.recursivePrinting(node.parent)  
    print(node.board)

  def search(self, board):
    self.count += 1
    #Initialise first Node with cost 0 (different for other algorithms)
    a = Node(copy.deepcopy(board), 0)
    self.opened.append(a)
    
    start_time = time.time()
    statessearched = 0
      
    while(1):              
        #If open list is empty, exit
        if(len(self.opened)==0):
            print("No Solution")

            #Write everything to file
            f = open("ucs-sol-"+ str(self.count) +".txt", "w")
            f.write("--------------------------------------------------------------------------------\n")
            f.write("Initial board configuration: " + board.stringLine())
            f.write("\n\n!\n" + str(board) + "\n")
            f.write("Car Fuel Available: ")
            for i in range(len(board.cars)):
                f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                if i < len(board.cars) - 1:
                  f.write(", ")
            f.write("\n Sorry, could not solve the puzzle as specified.\nError: no solution found\n")
            f.write("Runtime: " + str(time.time() - start_time) + " seconds")
            f.write("--------------------------------------------------------------------------------")
            f.close()

            return
        
        #Pop the best candidate node
        curr = self.opened.pop(0)
        
        #If the popped node is the solution, exit out and print stuff (later to file)
        if(curr.board.winConditionMet()):
            print("Initial board configuration")
            print()
            print(board)
            print("Car Fuel Available: ", end = '')
            for i in range(len(board.cars)):
                print(""+board.cars[i].letter+":"+str(board.cars[i].fuel)+", ", end ='')
            print()
            
            print("Runtime: %s seconds" % (time.time() - start_time))
            print("Number of moves: ", curr.cost)
            print("Search path length: %s states" % statessearched)

            print("------")
            #self.recursivePrinting(curr)

            ######

             #Write everything to file
            f = open("ucs-sol-"+ str(self.count) +".txt", "w")
            f.write("--------------------------------------------------------------------------------\n")
            f.write("Initial board configuration: " + board.stringLine())
            f.write("\n\n!\n" + str(board) + "\n")
            f.write("Car Fuel Available: ")
            for i in range(len(board.cars)):
                f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                if i < len(board.cars) - 1:
                  f.write(", ")
            f.write("\n")
            f.write("Runtime: " + str(time.time() - start_time) + " seconds")
            f.write("\nNumber of moves: " + str(curr.cost))
            f.write("\nSearch path length: " + str(statessearched) + " states")

            # Recursive here....


            f.write("\n\n! " + curr.board.AllUsedCars() + "\n")
            f.write(str(curr.board) + "\n")

            f.write("--------------------------------------------------------------------------------")
            f.close()

            return

        #If it's not a solution insert into closed list and increment counter
        self.closed.append(curr)
        statessearched+=1
        #print()
        for c in curr.board.cars:
            paths = curr.board.findCarPaths(c)    
            if len(paths) > 0:  
                #print("Car ", c.letter, " can move:", paths)
                
                for i in range(len(paths)):
                    #Create a new node for successor
                    #Increase the cost of this new node (different in other algorithms)
                    newnode = Node(Board(curr.board.cars), curr.cost+1)   
                    newnode.parent = curr                 
                
                    #Apply the move
                    newnode.board.moveCar(c.letter, paths[i])
                    
                    #If the item is already in the open list, skip it
                    #In other algos, need to check that cost is less
                    #For UCS, this will never be the case, since all costs are 1 in this case (breadth first search)
                    if newnode in self.opened or newnode in self.closed:
                        continue

                    #Insert into open list (in sorted order)
                    bisect.insort(self.opened, newnode)

# %%
currentBoard = Board(boards[46].cars)
ucs = UCS()
ucs.search(currentBoard, 0)
# Out:
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 53.17274737358093 seconds
# Number of moves:  11
# Search path length: 3037 states
# ------
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Z...O.
# ZB..OC
# .BAAOC
# .DPEFF
# .DPE..
# ..P...
#
# ZB..O.
# ZB..OC
# ..AAOC
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# ..AAO.
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# AA..O.
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# AA..O.
# ..PEFF
# .DPE..
# .DP...
#
# ZBP.OC
# ZBP.OC
# AAP.O.
# ...EFF
# .D.E..
# .D....
#
# ZBPEOC
# ZBPEOC
# AAP.O.
# ....FF
# .D....
# .D....
#
# ZBPEOC
# ZBPEOC
# AAP.O.
# FF....
# .D....
# .D....
#
# ZBPE.C
# ZBPE.C
# AAP...
# FF..O.
# .D..O.
# .D..O.
#
# ZB.E.C
# ZB.E.C
# AA....
# FFP.O.
# .DP.O.
# .DP.O.
#
# ZB.E.C
# ZB.E.C
# ....AA
# FFP.O.
# .DP.O.
# .DP.O.

# %% [markdown]
# # Building State Space Search - Greedy Best First Search (GBFS)

# %%
class HNode(object):
  def __init__(self, board, cost, parentCost):
    self.board = board
    self.cost = cost
    self.path = []
    self.parent = 0
    self.parentCost = parentCost
  def __lt__(self, other):
        return self.cost < other.cost
  def __eq__(self, other):
        return self.board == other.board
  def addHeuristic(self, heuristic):
        if heuristic == 1:
            self.cost = self.cost + self.board.h1()
        elif heuristic == 2:
            self.cost = self.cost + self.board.h2()
        elif heuristic == 3:
            self.cost = self.cost + self.board.h3(3)
        elif heuristic == 4:
            self.cost = self.cost + self.board.h4()
        return self.cost
  def setCost(self, cost):
        self.cost = cost
        
        
class GBFS(object):
    def __init__(self):
        self.opened = []
        self.closed = []
        self.count = 0
    
    def recursivePrinting(self, node):
        if node.cost != 0:
          self.recursivePrinting(node.parent)  
        print(node.board)
        
    def next(self):
        self.count += 1
        
    def search(self, board, heuristic):
        #Initialise first Node with cost 0
        a = HNode(copy.deepcopy(board), 0, -1)
        self.opened.append(a)
        
        start_time = time.time()
        statessearched = 0
      
        while(1):              
            #If open list is empty, exit
            if(len(self.opened)==0):
                print("No Solution")
                #Write everything to file
                f = open("gbfs-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("--------------------------------------------------------------------------------\n")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n!\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                      f.write(", ")
                f.write("\n Sorry, could not solve the puzzle as specified.\nError: no solution found\n")
                f.write("Runtime: " + str(time.time() - start_time) + " seconds")
                f.write("--------------------------------------------------------------------------------")
                f.close()
                return
        
            #Pop the best candidate node
            curr = self.opened.pop(0)
            curr.setCost(curr.parentCost + 1)
        
            #If the popped node is the solution, exit out and print stuff (later to file)
            if(curr.board.winConditionMet()):
                print("Initial board configuration")
                print()
                print(board)
                print("Car Fuel Available: ", end = '')
                for i in range(len(board.cars)):
                    print(""+board.cars[i].letter+":"+str(board.cars[i].fuel)+", ", end ='')
                print()
            
                print("Runtime: %s seconds" % (time.time() - start_time))
                print("Number of moves: ", curr.cost)
                print("Search path length: %s states" % statessearched)

                print("------")
                #self.recursivePrinting(curr)

                ######

                #Write everything to file
                f = open("gbfs-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("--------------------------------------------------------------------------------\n")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n!\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                      f.write(", ")
                f.write("\n")
                f.write("Runtime: " + str(time.time() - start_time) + " seconds")
                f.write("\nNumber of moves: " + str(curr.cost))
                f.write("\nSearch path length: " + str(statessearched) + " states")

                # Recursive here....


                f.write("\n\n! " + curr.board.AllUsedCars() + "\n")
                f.write(str(curr.board) + "\n")

                f.write("--------------------------------------------------------------------------------")
                f.close()

                return

            #If it's not a solution insert into closed list and increment counter
            self.closed.append(curr)
            statessearched+=1
        
            #print()
            for c in curr.board.cars:
                paths = curr.board.findCarPaths(c)    
                if len(paths) > 0:  
                    #print("Car ", c.letter, " can move:", paths)
                    
                    for i in range(len(paths)):
                        #Create a new node for successor
                        newnode = HNode(Board(curr.board.cars), 0, curr.cost)   
                        newnode.parent = curr                 
                
                        #Apply the move
                        newnode.board.moveCar(c.letter, paths[i])
                        newnode.addHeuristic(heuristic)
                    
                        #If the node is already in the open or closed list, skip it
                        if newnode in self.opened or newnode in self.closed:
                            continue

                        #Insert into open list (in sorted order)
                        bisect.insort(self.opened, newnode)

# %%
currentBoard = Board(boards[46].cars)
gbfs = GBFS()
gbfs.search(currentBoard, 2)
# Out:
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 12.705652475357056 seconds
# Number of moves:  12
# Search path length: 1217 states
# ------
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# ....OC
# ZB..OC
# ZBAAO.
# .DPEFF
# .DPE..
# ..P...
#
# Z...OC
# ZB..OC
# .BAAO.
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# ..AAO.
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# AA..O.
# .DPEFF
# .DPE..
# ..P...
#
# ZB.EOC
# ZB.EOC
# AA..O.
# .DP.FF
# .DP...
# ..P...
#
# ZBPEOC
# ZBPEOC
# AAP.O.
# .D..FF
# .D....
# ......
#
# ZBPEOC
# ZBPEOC
# AAP.O.
# .DFF..
# .D....
# ......
#
# ZBPE.C
# ZBPE.C
# AAP...
# .DFFO.
# .D..O.
# ....O.
#
# ZBPE.C
# ZBPE.C
# AAP...
# ..FFO.
# .D..O.
# .D..O.
#
# ZBPE.C
# ZBPE.C
# AAP...
# FF..O.
# .D..O.
# .D..O.
#
# ZB.E.C
# ZB.E.C
# AA....
# FFP.O.
# .DP.O.
# .DP.O.
#
# ZB.E.C
# ZB.E.C
# ....AA
# FFP.O.
# .DP.O.
# .DP.O.

# %% [markdown]
# # Building State Space Search - Algorithm A or A* (A/A*)

# %%
class AAStar(object):
    def __init__(self):
        self.opened = []
        self.closed = []
        self.count = 0
    
    def recursivePrinting(self, node):
        if node.cost != 0:
          self.recursivePrinting(node.parent)  
        print(node.board)
        
    def next(self):
        self.count += 1
        
    def search(self, board, heuristic):
        #Initialise first Node with cost 0
        a = HNode(copy.deepcopy(board), 0, -1)
        
        self.opened.append(a)
        
        start_time = time.time()
        statessearched = 0
      
        while(1):              
            #If open list is empty, exit
            if(len(self.opened)==0):
                print("No Solution")
                #Write everything to file
                f = open("a-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("--------------------------------------------------------------------------------\n")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n!\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                      f.write(", ")
                f.write("\n Sorry, could not solve the puzzle as specified.\nError: no solution found\n")
                f.write("Runtime: " + str(time.time() - start_time) + " seconds")
                f.write("--------------------------------------------------------------------------------")
                f.close()
                return
        
            #Pop the best candidate node
            curr = self.opened.pop(0)
            curr.setCost(curr.parentCost + 1)
        
            #If the popped node is the solution, exit out and print stuff (later to file)
            if(curr.board.winConditionMet()):
                print("Initial board configuration")
                print()
                print(board)
                print("Car Fuel Available: ", end = '')
                for i in range(len(board.cars)):
                    print(""+board.cars[i].letter+":"+str(board.cars[i].fuel)+", ", end ='')
                print()
            
                print("Runtime: %s seconds" % (time.time() - start_time))
                print("Number of moves: ", curr.cost)
                print("Search path length: %s states" % statessearched)

                print("------")
                #self.recursivePrinting(curr)

                #Write everything to file
                f = open("a-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("--------------------------------------------------------------------------------\n")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n!\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                      f.write(", ")
                f.write("\n")
                f.write("Runtime: " + str(time.time() - start_time) + " seconds")
                f.write("\nNumber of moves: " + str(curr.cost))
                f.write("\nSearch path length: " + str(statessearched) + " states")

                # Recursive here....


                f.write("\n\n! " + curr.board.AllUsedCars() + "\n")
                f.write(str(curr.board) + "\n")

                f.write("--------------------------------------------------------------------------------")
                f.close()

                return

            #If it's not a solution insert into closed list and increment counter
            self.closed.append(curr)
            statessearched+=1
        
            #print()
            for c in curr.board.cars:
                paths = curr.board.findCarPaths(c)    
                if len(paths) > 0:  
                    #print("Car ", c.letter, " can move:", paths)
                    
                    for i in range(len(paths)):
                        #Create a new node for successor
                        newnode = HNode(Board(curr.board.cars), curr.cost+1, curr.cost)   
                        newnode.parent = curr                 
                
                        #Apply the move
                        newnode.board.moveCar(c.letter, paths[i])
                        newnode.addHeuristic(heuristic)
                    
                        #If the node is already in the open or closed list, skip if the cost in is higher, else replace
                        if newnode in self.opened:
                            for n in self.opened:
                                if n == newnode and n.cost > newnode.cost:
                                    self.opened.remove(n)
                                    bisect.insort(self.opened, newnode)
                                    break
                            continue
                        elif newnode in self.closed:
                            
                            continue
                        else:
                            #Insert into open list (in sorted order)
                            bisect.insort(self.opened, newnode)

# %%
currentBoard = Board(boards[46].cars)
aastar = AAStar()
aastar.search(currentBoard, 2)
# Out:
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 16.722499132156372 seconds
# Number of moves:  11
# Search path length: 2274 states
# ------
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# ....OC
# ZB..OC
# ZBAAO.
# .DPEFF
# .DPE..
# ..P...
#
# Z...OC
# ZB..OC
# .BAAO.
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# ..AAO.
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# AA..O.
# .DPEFF
# .DPE..
# ..P...
#
# ZB..OC
# ZB..OC
# AA..O.
# ..PEFF
# .DPE..
# .DP...
#
# ZB.EOC
# ZB.EOC
# AA..O.
# ..P.FF
# .DP...
# .DP...
#
# ZBPEOC
# ZBPEOC
# AAP.O.
# ....FF
# .D....
# .D....
#
# ZBPEOC
# ZBPEOC
# AAP.O.
# FF....
# .D....
# .D....
#
# ZBPE.C
# ZBPE.C
# AAP...
# FF..O.
# .D..O.
# .D..O.
#
# ZB.E.C
# ZB.E.C
# AA....
# FFP.O.
# .DP.O.
# .DP.O.
#
# ZB.E.C
# ZB.E.C
# ....AA
# FFP.O.
# .DP.O.
# .DP.O.

# %% [markdown]
# # Output to File

# %%
ucs = UCS()

for b in boards:
    currentBoard = Board(b.cars) 
    ucs.search(currentBoard)

# %%
gbfs = GBFS()

for b in boards:
    currentBoard = Board(b.cars) 
    gbfs.next()
    for i in range(1,5): 
        gbfs.search(currentBoard, i)

# %%
aastar = AAStar()

for b in boards:
    currentBoard = Board(b.cars) 
    aastar.next()
    for i in range(1,5): 
        aastar.search(currentBoard, i)
# Out:
# Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 5.570498943328857 seconds
# Number of moves:  9
# Search path length: 1199 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# ....AA
# ZDB...
# ZDBPPP
# ......
#
# Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.0305025577545166 seconds
# Number of moves:  9
# Search path length: 4 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZD....
# ZDBPPP
# ..B...
#
# OOOC.E
# ...C.E
# ....AA
# ZD....
# ZDBPPP
# ..B...
#
# Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.03199934959411621 seconds
# Number of moves:  9
# Search path length: 4 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# ....AA
# .DB...
# ZDBPPP
# Z.....
#
# Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.03349900245666504 seconds
# Number of moves:  9
# Search path length: 4 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .D....
# ZDBPPP
# Z.B...
#
# OOOC.E
# ...C.E
# ....AA
# .D....
# ZDBPPP
# Z.B...
#
# Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 2.863996982574463 seconds
# Number of moves:  10
# Search path length: 419 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# Z.B...
# ZDBPPP
# .D....
#
# OOOC.E
# ...C.E
# ....AA
# Z.B...
# ZDBPPP
# .D....
#
# Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 0.0840001106262207 seconds
# Number of moves:  10
# Search path length: 12 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZD....
# ZDBPPP
# ..B...
#
# OOOC.E
# ...C.E
# AA....
# Z.....
# ZDBPPP
# .DB...
#
# OOOC.E
# ...C.E
# ....AA
# Z.....
# ZDBPPP
# .DB...
#
# Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 0.06749916076660156 seconds
# Number of moves:  10
# Search path length: 10 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# ..B...
# ZDBPPP
# ZD....
#
# OOOC.E
# ...C.E
# ....AA
# ..B...
# ZDBPPP
# ZD....
#
# Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 5.50849723815918 seconds
# Number of moves:  5
# Search path length: 623 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZ.
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# ..DD.C
#
# ...ZZB
# .....B
# .AA...
# ....O.
# ....OC
# ..DDOC
#
# ...ZZB
# .....B
# ....AA
# ....O.
# ....OC
# ..DDOC
#
# Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.009496927261352539 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZ.
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# .DD..C
#
# ...ZZB
# .....B
# .AA...
# ....O.
# ....OC
# .DD.OC
#
# ...ZZB
# .....B
# ....AA
# ....O.
# ....OC
# .DD.OC
#
# Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.010997295379638672 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZ.
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# DD...C
#
# ...ZZB
# .....B
# .AA...
# ....O.
# ....OC
# DD..OC
#
# ...ZZB
# .....B
# ....AA
# ....O.
# ....OC
# DD..OC
#
# Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.4479982852935791 seconds
# Number of moves:  5
# Search path length: 42 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ..
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# ..DD.C
#
# ..ZZ.B
# .....B
# .AA...
# ....O.
# ....OC
# ..DDOC
#
# ..ZZ.B
# .....B
# ....AA
# ....O.
# ....OC
# ..DDOC
#
# Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.010498762130737305 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ..
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# .DD..C
#
# ..ZZ.B
# .....B
# .AA...
# ....O.
# ....OC
# .DD.OC
#
# ..ZZ.B
# .....B
# ....AA
# ....O.
# ....OC
# .DD.OC
#
# Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.010997295379638672 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ..
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# DD...C
#
# ..ZZ.B
# .....B
# .AA...
# ....O.
# ....OC
# DD..OC
#
# ..ZZ.B
# .....B
# ....AA
# ....O.
# ....OC
# DD..OC
#
# Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.5059983730316162 seconds
# Number of moves:  5
# Search path length: 42 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ...
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# ..DD.C
#
# .ZZ..B
# .....B
# .AA...
# ....O.
# ....OC
# ..DDOC
#
# .ZZ..B
# .....B
# ....AA
# ....O.
# ....OC
# ..DDOC
#
# Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.010499238967895508 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ...
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# .DD..C
#
# .ZZ..B
# .....B
# .AA...
# ....O.
# ....OC
# .DD.OC
#
# .ZZ..B
# .....B
# ....AA
# ....O.
# ....OC
# .DD.OC
#
# Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.010500192642211914 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ...
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# DD...C
#
# .ZZ..B
# .....B
# .AA...
# ....O.
# ....OC
# DD..OC
#
# .ZZ..B
# .....B
# ....AA
# ....O.
# ....OC
# DD..OC
#
# Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.5004997253417969 seconds
# Number of moves:  5
# Search path length: 42 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ....
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# ..DD.C
#
# ZZ...B
# .....B
# .AA...
# ....O.
# ....OC
# ..DDOC
#
# ZZ...B
# .....B
# ....AA
# ....O.
# ....OC
# ..DDOC
#
# Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.010499238967895508 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ....
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# .DD..C
#
# ZZ...B
# .....B
# .AA...
# ....O.
# ....OC
# .DD.OC
#
# ZZ...B
# .....B
# ....AA
# ....O.
# ....OC
# .DD.OC
#
# Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.01100015640258789 seconds
# Number of moves:  5
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ....
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# DD...C
#
# ZZ...B
# .....B
# .AA...
# ....O.
# ....OC
# DD..OC
#
# ZZ...B
# .....B
# ....AA
# ....O.
# ....OC
# DD..OC
#
# Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 4.020501136779785 seconds
# Number of moves:  6
# Search path length: 282 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZ.
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ...ZZB
# ....OB
# .AA.O.
# ....OC
# .....C
# ..DD..
#
# ...ZZB
# .....B
# .AA...
# ....OC
# ....OC
# ..DDO.
#
# ...ZZB
# .....B
# ....AA
# ....OC
# ....OC
# ..DDO.
#
# Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.008999109268188477 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZ.
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ...ZZB
# ....OB
# .AA.O.
# ....OC
# .....C
# .DD...
#
# ...ZZB
# .....B
# .AA...
# ....OC
# ....OC
# .DD.O.
#
# ...ZZB
# .....B
# ....AA
# ....OC
# ....OC
# .DD.O.
#
# Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.013498783111572266 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZ.
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ...ZZB
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ...ZZB
# ....OB
# .AA.O.
# ....OC
# .....C
# DD....
#
# ...ZZB
# .....B
# .AA...
# ....OC
# ....OC
# DD..O.
#
# ...ZZB
# .....B
# ....AA
# ....OC
# ....OC
# DD..O.
#
# Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.0709993839263916 seconds
# Number of moves:  6
# Search path length: 7 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ..
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....OC
# .....C
# ..DD..
#
# ..ZZ.B
# .....B
# .AA...
# ....OC
# ....OC
# ..DDO.
#
# ..ZZ.B
# .....B
# ....AA
# ....OC
# ....OC
# ..DDO.
#
# Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.009500503540039062 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ..
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....OC
# .....C
# .DD...
#
# ..ZZ.B
# .....B
# .AA...
# ....OC
# ....OC
# .DD.O.
#
# ..ZZ.B
# .....B
# ....AA
# ....OC
# ....OC
# .DD.O.
#
# Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.011499404907226562 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ..
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ..ZZ.B
# ....OB
# .AA.O.
# ....OC
# .....C
# DD....
#
# ..ZZ.B
# .....B
# .AA...
# ....OC
# ....OC
# DD..O.
#
# ..ZZ.B
# .....B
# ....AA
# ....OC
# ....OC
# DD..O.
#
# Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.07950019836425781 seconds
# Number of moves:  6
# Search path length: 7 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ...
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# .ZZ..B
# ....OB
# .AA.O.
# ....OC
# .....C
# ..DD..
#
# .ZZ..B
# .....B
# .AA...
# ....OC
# ....OC
# ..DDO.
#
# .ZZ..B
# .....B
# ....AA
# ....OC
# ....OC
# ..DDO.
#
# Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.012998342514038086 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ...
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# .ZZ..B
# ....OB
# .AA.O.
# ....OC
# .....C
# .DD...
#
# .ZZ..B
# .....B
# .AA...
# ....OC
# ....OC
# .DD.O.
#
# .ZZ..B
# .....B
# ....AA
# ....OC
# ....OC
# .DD.O.
#
# Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.012000560760498047 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ...
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# .ZZ..B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# .ZZ..B
# ....OB
# .AA.O.
# ....OC
# .....C
# DD....
#
# .ZZ..B
# .....B
# .AA...
# ....OC
# ....OC
# DD..O.
#
# .ZZ..B
# .....B
# ....AA
# ....OC
# ....OC
# DD..O.
#
# Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.0834968090057373 seconds
# Number of moves:  6
# Search path length: 7 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ....
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ZZ...B
# ....OB
# .AA.O.
# ....OC
# .....C
# ..DD..
#
# ZZ...B
# .....B
# .AA...
# ....OC
# ....OC
# ..DDO.
#
# ZZ...B
# .....B
# ....AA
# ....OC
# ....OC
# ..DDO.
#
# Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.011500835418701172 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ....
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ZZ...B
# ....OB
# .AA.O.
# ....OC
# .....C
# .DD...
#
# ZZ...B
# .....B
# .AA...
# ....OC
# ....OC
# .DD.O.
#
# ZZ...B
# .....B
# ....AA
# ....OC
# ....OC
# .DD.O.
#
# Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.011999130249023438 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ....
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....O.
# .....C
# ...DDC
#
# ZZ...B
# ....OB
# .AA.O.
# ....OC
# .....C
# ...DD.
#
# ZZ...B
# ....OB
# .AA.O.
# ....OC
# .....C
# DD....
#
# ZZ...B
# .....B
# .AA...
# ....OC
# ....OC
# DD..O.
#
# ZZ...B
# .....B
# ....AA
# ....OC
# ....OC
# DD..O.
#
# Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 2.448000431060791 seconds
# Number of moves:  10
# Search path length: 232 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .D....
# ZDBPPP
# Z.B...
#
# OOOC.E
# ...C.E
# AA....
# ......
# ZDBPPP
# ZDB...
#
# OOOC.E
# ...C.E
# ....AA
# ......
# ZDBPPP
# ZDB...
#
# Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.1439990997314453 seconds
# Number of moves:  10
# Search path length: 16 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .DPPP.
# ......
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .D.PPP
# ......
#
# Z..OOO
# Z.....
# AA.C.E
# .DBC.E
# .DBPPP
# ......
#
# Z..OOO
# Z.....
# .AAC.E
# .DBC.E
# .DBPPP
# ......
#
# ...OOO
# Z.....
# ZAAC.E
# .DBC.E
# .DBPPP
# ......
#
# OOO...
# Z.....
# ZAAC.E
# .DBC.E
# .DBPPP
# ......
#
# OOOC..
# Z..C..
# ZAA..E
# .DB..E
# .DBPPP
# ......
#
# OOOC.E
# Z..C.E
# ZAA...
# .DB...
# .DBPPP
# ......
#
# OOOC.E
# Z..C.E
# Z...AA
# .DB...
# .DBPPP
# ......
#
# Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.009999513626098633 seconds
# Number of moves:  10
# Search path length: 1 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .DPPP.
# ......
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .D.PPP
# ......
#
# Z..OOO
# Z.....
# AA.C.E
# .DBC.E
# .DBPPP
# ......
#
# Z..OOO
# Z.....
# .AAC.E
# .DBC.E
# .DBPPP
# ......
#
# ...OOO
# ......
# ZAAC.E
# ZDBC.E
# .DBPPP
# ......
#
# OOO...
# ......
# ZAAC.E
# ZDBC.E
# .DBPPP
# ......
#
# OOOC..
# ...C..
# ZAA..E
# ZDB..E
# .DBPPP
# ......
#
# OOOC.E
# ...C.E
# ZAA...
# ZDB...
# .DBPPP
# ......
#
# OOOC.E
# ...C.E
# Z...AA
# ZDB...
# .DBPPP
# ......
#
# Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.018501996994018555 seconds
# Number of moves:  10
# Search path length: 1 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .DPPP.
# ......
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .D.PPP
# ......
#
# Z..OOO
# Z.....
# AA.C.E
# .D.C.E
# .DBPPP
# ..B...
#
# Z..OOO
# Z.....
# .AAC.E
# .D.C.E
# .DBPPP
# ..B...
#
# ...OOO
# Z.....
# ZAAC.E
# .D.C.E
# .DBPPP
# ..B...
#
# OOO...
# Z.....
# ZAAC.E
# .D.C.E
# .DBPPP
# ..B...
#
# OOOC..
# Z..C..
# ZAA..E
# .D...E
# .DBPPP
# ..B...
#
# OOOC.E
# Z..C.E
# ZAA...
# .D....
# .DBPPP
# ..B...
#
# OOOC.E
# Z..C.E
# Z...AA
# .D....
# .DBPPP
# ..B...
#
# Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.013997793197631836 seconds
# Number of moves:  10
# Search path length: 1 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .DPPP.
# ......
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .D.PPP
# ......
#
# Z..OOO
# Z.....
# AA.C.E
# .D.C.E
# .DBPPP
# ..B...
#
# Z..OOO
# Z.....
# .AAC.E
# .D.C.E
# .DBPPP
# ..B...
#
# ...OOO
# ......
# ZAAC.E
# ZD.C.E
# .DBPPP
# ..B...
#
# OOO...
# ......
# ZAAC.E
# ZD.C.E
# .DBPPP
# ..B...
#
# OOOC..
# ...C..
# ZAA..E
# ZD...E
# .DBPPP
# ..B...
#
# OOOC.E
# ...C.E
# ZAA...
# ZD....
# .DBPPP
# ..B...
#
# OOOC.E
# ...C.E
# Z...AA
# ZD....
# .DBPPP
# ..B...
#
# Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 1.8419995307922363 seconds
# Number of moves:  11
# Search path length: 187 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# ..AA..
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# .DAA..
# ZDB...
# Z.BPPP
# ......
#
# OOOC.E
# ...C.E
# .D..AA
# ZDB...
# Z.BPPP
# ......
#
# Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 0.0 seconds
# Number of moves:  11
# Search path length: 0 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# ..AA..
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# .D.C.E
# .DAA..
# Z.B...
# Z.BPPP
# ......
#
# OOOC.E
# .D.C.E
# .D..AA
# Z.B...
# Z.BPPP
# ......
#
# Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 0.12499785423278809 seconds
# Number of moves:  11
# Search path length: 10 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# ...AA.
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# ..BAA.
# ZDB...
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# ..B.AA
# ZDB...
# ZD.PPP
# ......
#
# Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 0.03899812698364258 seconds
# Number of moves:  11
# Search path length: 4 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ...C.E
# ...AA.
# ZDB...
# ZDBPPP
# ......
#
# OOOC.E
# ..BC.E
# ..BAA.
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ..BC.E
# ..B.AA
# ZD....
# ZD.PPP
# ......
#
# Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.10199737548828125 seconds
# Number of moves:  11
# Search path length: 11 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZD....
# ZDBPPP
# ..B...
#
# OOOC.E
# ...C.E
# ..AA..
# ZD....
# ZDBPPP
# ..B...
#
# OOOC.E
# ...C.E
# .DAA..
# ZD....
# Z.BPPP
# ..B...
#
# OOOC.E
# ...C.E
# .D..AA
# ZD....
# Z.BPPP
# ..B...
#
# Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.0 seconds
# Number of moves:  11
# Search path length: 0 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# ZD.C..
# ZDPPPE
# .....E
#
# ..BOOO
# ..B...
# AA.C..
# ZD.C..
# ZDPPPE
# .....E
#
# ...OOO
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOO...
# ..B...
# AABC..
# ZD.C..
# ZDPPPE
# .....E
#
# OOOC..
# ..BC..
# AAB...
# ZD....
# ZDPPPE
# .....E
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZDPPP.
# ......
#
# OOOC.E
# ..BC.E
# AAB...
# ZD....
# ZD.PPP
# ......
#
# OOOC.E
# ...C.E
# AA....
# ZD....
# ZDBPPP
# ..B...
#
# OOOC.E
# ...C.E
# ..AA..
# ZD....
# ZDBPPP
# ..B...
#
# OOOC.E
# .D.C.E
# .DAA..
# Z.....
# Z.BPPP
# ..B...
#
# OOOC.E
# .D.C.E
# .D..AA
# Z.....
# Z.BPPP
# ..B...
#
# Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.07999944686889648 seconds
# Number of moves:  11
# Search path length: 7 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# ..AA..
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# .DAA..
# .DB...
# Z.BPPP
# Z.....
#
# OOOC.E
# ...C.E
# .D..AA
# .DB...
# Z.BPPP
# Z.....
#
# Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.0 seconds
# Number of moves:  11
# Search path length: 0 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# ..AA..
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# .D.C.E
# .DAA..
# ..B...
# Z.BPPP
# Z.....
#
# OOOC.E
# .D.C.E
# .D..AA
# ..B...
# Z.BPPP
# Z.....
#
# Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 0.0 seconds
# Number of moves:  11
# Search path length: 0 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# ...AA.
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# ..BAA.
# .DB...
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# ..B.AA
# .DB...
# ZD.PPP
# Z.....
#
# Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 0.05299544334411621 seconds
# Number of moves:  11
# Search path length: 4 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ...C.E
# ...AA.
# .DB...
# ZDBPPP
# Z.....
#
# OOOC.E
# ..BC.E
# ..BAA.
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ..BC.E
# ..B.AA
# .D....
# ZD.PPP
# Z.....
#
# Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 0.0670013427734375 seconds
# Number of moves:  11
# Search path length: 5 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .D....
# ZDBPPP
# Z.B...
#
# OOOC.E
# ...C.E
# ..AA..
# .D....
# ZDBPPP
# Z.B...
#
# OOOC.E
# ...C.E
# .DAA..
# .D....
# Z.BPPP
# Z.B...
#
# OOOC.E
# ...C.E
# .D..AA
# .D....
# Z.BPPP
# Z.B...
#
# Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 0.0 seconds
# Number of moves:  11
# Search path length: 0 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# ..BOOO
# ..B...
# .AAC..
# .D.C..
# ZDPPPE
# Z....E
#
# ..BOOO
# ..B...
# AA.C..
# .D.C..
# ZDPPPE
# Z....E
#
# ...OOO
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOO...
# ..B...
# AABC..
# .D.C..
# ZDPPPE
# Z....E
#
# OOOC..
# ..BC..
# AAB...
# .D....
# ZDPPPE
# Z....E
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZDPPP.
# Z.....
#
# OOOC.E
# ..BC.E
# AAB...
# .D....
# ZD.PPP
# Z.....
#
# OOOC.E
# ...C.E
# AA....
# .D....
# ZDBPPP
# Z.B...
#
# OOOC.E
# ...C.E
# ..AA..
# .D....
# ZDBPPP
# Z.B...
#
# OOOC.E
# .D.C.E
# .DAA..
# ......
# Z.BPPP
# Z.B...
#
# OOOC.E
# .D.C.E
# .D..AA
# ......
# Z.BPPP
# Z.B...
#
# Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 0.37150096893310547 seconds
# Number of moves:  11
# Search path length: 46 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .DPPP.
# ......
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .D.PPP
# ......
#
# Z..OOO
# Z.....
# AA.C.E
# .DBC.E
# .DBPPP
# ......
#
# Z..OOO
# Z.....
# .AAC.E
# .DBC.E
# .DBPPP
# ......
#
# ...OOO
# Z.....
# ZAAC.E
# .DBC.E
# .DBPPP
# ......
#
# OOO...
# Z.....
# ZAAC.E
# .DBC.E
# .DBPPP
# ......
#
# OOOC..
# Z..C..
# ZAA..E
# .DB..E
# .DBPPP
# ......
#
# OOOC.E
# Z..C.E
# ZAA...
# .DB...
# .DBPPP
# ......
#
# OOOC.E
# Z..C.E
# ZAA...
# ..B...
# .DBPPP
# .D....
#
# OOOC.E
# Z..C.E
# Z...AA
# ..B...
# .DBPPP
# .D....
#
# Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 0.0019981861114501953 seconds
# Number of moves:  11
# Search path length: 1 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .DPPP.
# ......
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .D.PPP
# ......
#
# Z..OOO
# Z.....
# AA.C.E
# .DBC.E
# .DBPPP
# ......
#
# Z..OOO
# Z.....
# .AAC.E
# .DBC.E
# .DBPPP
# ......
#
# ...OOO
# ......
# ZAAC.E
# ZDBC.E
# .DBPPP
# ......
#
# OOO...
# ......
# ZAAC.E
# ZDBC.E
# .DBPPP
# ......
#
# OOOC..
# ...C..
# ZAA..E
# ZDB..E
# .DBPPP
# ......
#
# OOOC.E
# ...C.E
# ZAA...
# ZDB...
# .DBPPP
# ......
#
# OOOC.E
# ...C.E
# ZAA...
# Z.B...
# .DBPPP
# .D....
#
# OOOC.E
# ...C.E
# Z...AA
# Z.B...
# .DBPPP
# .D....
#
# Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 0.0014977455139160156 seconds
# Number of moves:  11
# Search path length: 1 states
# ------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C..
# .D.C..
# .DPPPE
# .....E
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .DPPP.
# ......
#
# Z.BOOO
# Z.B...
# AA.C.E
# .D.C.E
# .D.PPP
# ......
#
# Z..OOO
# Z.....
# AA.C.E
# .D.C.E
# .DBPPP
# ..B...
#
# Z..OOO
# Z.....
# .AAC.E
# .D.C.E
# .DBPPP
# ..B...
#
# ...OOO
# Z.....
# ZAAC.E
# .D.C.E
# .DBPPP
# ..B...
#
# OOO...
# Z.....
# ZAAC.E
# .D.C.E
# .DBPPP
# ..B...
#
# OOOC..
# Z..C..
# ZAA..E
# .D...E
# .DBPPP
# ..B...
#
# OOOC.E
# Z..C.E
# ZAA...
# .D....
# .DBPPP
# ..B...
#
# OOOC.E
# Z..C.E
# ZAA...
# ......
# .DBPPP
# .DB...
#
# OOOC.E
# Z..C.E
# Z...AA
# ......
# .DBPPP
# .DB...
#
# Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 255.07199549674988 seconds
# Number of moves:  6
# Search path length: 5249 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# .AAO.Z
# B.....
# B.C...
# ..CPPP
#
# ...O.Z
# ...O.Z
# .AAO..
# B.....
# B.C...
# ..CPPP
#
# ...O.Z
# ...O.Z
# .AAO..
# B.C...
# B.C...
# ...PPP
#
# ...O.Z
# ...O.Z
# .AAO..
# B.C...
# B.C...
# PPP...
#
# .....Z
# .....Z
# .AA...
# B.CO..
# B.CO..
# PPPO..
#
# .....Z
# .....Z
# ....AA
# B.CO..
# B.CO..
# PPPO..
#
# Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.13649964332580566 seconds
# Number of moves:  6
# Search path length: 2 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# .AAO.Z
# B.....
# B.C...
# ..CPPP
#
# ...O..
# ...O..
# .AAO..
# B....Z
# B.C..Z
# ..CPPP
#
# ...O..
# ...O..
# .AAO..
# B.C..Z
# B.C..Z
# ...PPP
#
# ...O..
# ...O..
# .AAO..
# B.C..Z
# B.C..Z
# PPP...
#
# ......
# ......
# .AA...
# B.CO.Z
# B.CO.Z
# PPPO..
#
# ......
# ......
# ....AA
# B.CO.Z
# B.CO.Z
# PPPO..
#
# Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.22099709510803223 seconds
# Number of moves:  6
# Search path length: 4 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# BAAO.Z
# B.....
# ..C...
# ..CPPP
#
# ...O.Z
# ...O.Z
# BAAO..
# B.....
# ..C...
# ..CPPP
#
# ...O.Z
# ...O.Z
# BAAO..
# B.C...
# ..C...
# ...PPP
#
# ...O.Z
# ...O.Z
# BAAO..
# B.C...
# ..C...
# PPP...
#
# .....Z
# .....Z
# BAA...
# B.CO..
# ..CO..
# PPPO..
#
# .....Z
# .....Z
# B...AA
# B.CO..
# ..CO..
# PPPO..
#
# Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.14350056648254395 seconds
# Number of moves:  6
# Search path length: 2 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# BAAO.Z
# B.....
# ..C...
# ..CPPP
#
# ...O..
# ...O..
# BAAO..
# B....Z
# ..C..Z
# ..CPPP
#
# ...O..
# ...O..
# BAAO..
# B.C..Z
# ..C..Z
# ...PPP
#
# ...O..
# ...O..
# BAAO..
# B.C..Z
# ..C..Z
# PPP...
#
# ......
# ......
# BAA...
# B.CO.Z
# ..CO.Z
# PPPO..
#
# ......
# ......
# B...AA
# B.CO.Z
# ..CO.Z
# PPPO..
#
# Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.25999999046325684 seconds
# Number of moves:  6
# Search path length: 4 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ......
# ..C...
# ..CPPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ......
# ..C...
# ..CPPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ..C...
# ..C...
# ...PPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ..C...
# ..C...
# PPP...
#
# .....Z
# B....Z
# BAA...
# ..CO..
# ..CO..
# PPPO..
#
# .....Z
# B....Z
# B...AA
# ..CO..
# ..CO..
# PPPO..
#
# Initial board configuration
#
# ...OOO
# ....P.
# ..AAP.
# .QQQP.
# ..ZBCC
# ..ZB..
#
# Car Fuel Available: O:100, P:100, A:100, Q:100, Z:100, B:100, C:100,
# Runtime: 0.16299772262573242 seconds
# Number of moves:  6
# Search path length: 2 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ......
# ..C...
# ..CPPP
#
# ...O..
# B..O..
# BAAO..
# .....Z
# ..C..Z
# ..CPPP
#
# ...O..
# B..O..
# BAAO..
# ..C..Z
# ..C..Z
# ...PPP
#
# ...O..
# B..O..
# BAAO..
# ..C..Z
# ..C..Z
# PPP...
#
# ......
# B.....
# BAA...
# ..CO.Z
# ..CO.Z
# PPPO..
#
# ......
# B.....
# B...AA
# ..CO.Z
# ..CO.Z
# PPPO..
#
# Initial board configuration
#
# ...OOO
# ....P.
# ..AAP.
# .QQQP.
# ..ZBCC
# ..ZB..
#
# Car Fuel Available: O:100, P:100, A:100, Q:100, Z:100, B:100, C:100,
# Runtime: 4.0374956130981445 seconds
# Number of moves:  6
# Search path length: 60 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ......
# ..C...
# ..CPPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ......
# ..C...
# ..CPPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ..C...
# ..C...
# ...PPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ..C...
# ..C...
# PPP...
#
# B....Z
# B....Z
# .AA...
# ..CO..
# ..CO..
# PPPO..
#
# B....Z
# B....Z
# ....AA
# ..CO..
# ..CO..
# PPPO..
#
# Initial board configuration
#
# ...OOO
# ....P.
# ..AAP.
# .QQQP.
# ..ZBCC
# ..ZB..
#
# Car Fuel Available: O:100, P:100, A:100, Q:100, Z:100, B:100, C:100,
# Runtime: 2.4814977645874023 seconds
# Number of moves:  6
# Search path length: 30 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ......
# ..C...
# ..CPPP
#
# B..O..
# B..O..
# .AAO..
# .....Z
# ..C..Z
# ..CPPP
#
# B..O..
# B..O..
# .AAO..
# ..C..Z
# ..C..Z
# ...PPP
#
# B..O..
# B..O..
# .AAO..
# ..C..Z
# ..C..Z
# PPP...
#
# B.....
# B.....
# .AA...
# ..CO.Z
# ..CO.Z
# PPPO..
#
# B.....
# B.....
# ....AA
# ..CO.Z
# ..CO.Z
# PPPO..
#
# Initial board configuration
#
# ...OOO
# ....P.
# ..AAP.
# .QQQP.
# ..ZBCC
# ..ZB..
#
# Car Fuel Available: O:100, P:100, A:100, Q:100, Z:100, B:100, C:100,
# Runtime: 4.529500722885132 seconds
# Number of moves:  6
# Search path length: 71 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# PPP...
# ......
# ......
#
# ZOOO.D
# Z.B..D
# AAB...
# PPP...
# ...C..
# ...C..
#
# ZOOO.D
# Z.B..D
# AAB...
# ...PPP
# ...C..
# ...C..
#
# ZOOO.D
# Z....D
# AA....
# ..BPPP
# ..BC..
# ...C..
#
# ZOOO.D
# Z....D
# ....AA
# ..BPPP
# ..BC..
# ...C..
#
# Initial board configuration
#
# Z.O...
# Z.O...
# AAO...
# ......
# .BBC.D
# PPPC.D
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.34999656677246094 seconds
# Number of moves:  6
# Search path length: 3 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# PPP...
# ......
# ......
#
# ZOOO.D
# Z.B..D
# AAB...
# PPP...
# ...C..
# ...C..
#
# ZOOO.D
# Z.B..D
# AAB...
# ...PPP
# ...C..
# ...C..
#
# ZOOO.D
# Z....D
# AA....
# ...PPP
# ..BC..
# ..BC..
#
# ZOOO.D
# Z....D
# ....AA
# ...PPP
# ..BC..
# ..BC..
#
# Initial board configuration
#
# Z.O...
# Z.O...
# AAO...
# ......
# .BBC.D
# PPPC.D
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 2.8864948749542236 seconds
# Number of moves:  6
# Search path length: 36 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ...PPP
# ......
# ......
#
# ZOOO.D
# Z..C.D
# AA.C..
# ...PPP
# ..B...
# ..B...
#
# ZOOO.D
# Z..C.D
# AA.C..
# PPP...
# ..B...
# ..B...
#
# ZOOO.D
# Z....D
# AA....
# PPPC..
# ..BC..
# ..B...
#
# ZOOO.D
# Z....D
# ....AA
# PPPC..
# ..BC..
# ..B...
#
# Initial board configuration
#
# Z.O...
# Z.O...
# AAO...
# ......
# .BBC.D
# PPPC.D
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.30638694763183594 seconds
# Number of moves:  6
# Search path length: 3 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ...PPP
# ......
# ......
#
# ZOOO.D
# Z..C.D
# AA.C..
# ...PPP
# ..B...
# ..B...
#
# ZOOO.D
# Z..C.D
# AA.C..
# PPP...
# ..B...
# ..B...
#
# ZOOO.D
# Z....D
# AA....
# PPP...
# ..BC..
# ..BC..
#
# ZOOO.D
# Z....D
# ....AA
# PPP...
# ..BC..
# ..BC..
#
# Initial board configuration
#
# Z.O...
# Z.O...
# AAO...
# ......
# .BBC.D
# PPPC.D
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 4.4789979457855225 seconds
# Number of moves:  6
# Search path length: 67 states
# ------
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# DD.PPP
# ......
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# DDPPP.
# ......
#
# .....Z
# ..OOOZ
# AA.B..
# ...B.C
# DDPPPC
# ......
#
# .....Z
# OOO..Z
# AA.B..
# ...B.C
# DDPPPC
# ......
#
# ...B.Z
# OOOB.Z
# AA....
# .....C
# DDPPPC
# ......
#
# ...B.Z
# OOOB.Z
# ....AA
# .....C
# DDPPPC
# ......
#
# Initial board configuration
#
# ..OPPP
# ..OZ.Q
# AAOZBQ
# ...RBQ
# .CCRD.
# ...RD.
#
# Car Fuel Available: O:100, P:100, Z:100, Q:100, A:100, B:100, R:100, C:100, D:100,
# Runtime: 0.29349756240844727 seconds
# Number of moves:  6
# Search path length: 4 states
# ------
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# DD.PPP
# ......
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# DDPPP.
# ......
#
# .....Z
# ..OOOZ
# AA.B..
# ...B..
# DDPPPC
# .....C
#
# .....Z
# OOO..Z
# AA.B..
# ...B..
# DDPPPC
# .....C
#
# ...B.Z
# OOOB.Z
# AA....
# ......
# DDPPPC
# .....C
#
# ...B.Z
# OOOB.Z
# ....AA
# ......
# DDPPPC
# .....C
#
# Initial board configuration
#
# ..OPPP
# ..OZ.Q
# AAOZBQ
# ...RBQ
# .CCRD.
# ...RD.
#
# Car Fuel Available: O:100, P:100, Z:100, Q:100, A:100, B:100, R:100, C:100, D:100,
# Runtime: 6.086998224258423 seconds
# Number of moves:  6
# Search path length: 90 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..ZP.B
# AA.P.B
# ...P..
# .....C
# .....C
#
# ...OOO
# ...P.B
# AA.P.B
# ..ZP..
# ..Z..C
# .....C
#
# ..OOO.
# ...P.B
# AA.P.B
# ..ZP..
# ..Z..C
# .....C
#
# ..OOOB
# ...P.B
# AA.P..
# ..ZP..
# ..Z..C
# .....C
#
# ..OOOB
# .....B
# AA....
# ..ZP..
# ..ZP.C
# ...P.C
#
# ..OOOB
# .....B
# ....AA
# ..ZP..
# ..ZP.C
# ...P.C
#
# Initial board configuration
#
# ..OPPP
# ..OZ.Q
# AAOZBQ
# ...RBQ
# .CCRD.
# ...RD.
#
# Car Fuel Available: O:100, P:100, Z:100, Q:100, A:100, B:100, R:100, C:100, D:100,
# Runtime: 0.43149876594543457 seconds
# Number of moves:  6
# Search path length: 6 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..ZP.B
# AA.P.B
# ...P..
# .....C
# .....C
#
# ...OOO
# ...P.B
# AA.P.B
# ..ZP..
# ..Z..C
# .....C
#
# .OOO..
# ...P.B
# AA.P.B
# ..ZP..
# ..Z..C
# .....C
#
# .OOO.B
# ...P.B
# AA.P..
# ..ZP..
# ..Z..C
# .....C
#
# .OOO.B
# .....B
# AA....
# ..ZP..
# ..ZP.C
# ...P.C
#
# .OOO.B
# .....B
# ....AA
# ..ZP..
# ..ZP.C
# ...P.C
#
# Initial board configuration
#
# ..OPPP
# ..OZ.Q
# AAOZBQ
# ...RBQ
# .CCRD.
# ...RD.
#
# Car Fuel Available: O:100, P:100, Z:100, Q:100, A:100, B:100, R:100, C:100, D:100,
# Runtime: 0.6174962520599365 seconds
# Number of moves:  6
# Search path length: 8 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..ZP.B
# AA.P.B
# ...P..
# .....C
# .....C
#
# ...OOO
# ...P.B
# AA.P.B
# ..ZP..
# ..Z..C
# .....C
#
# OOO...
# ...P.B
# AA.P.B
# ..ZP..
# ..Z..C
# .....C
#
# OOO..B
# ...P.B
# AA.P..
# ..ZP..
# ..Z..C
# .....C
#
# OOO..B
# .....B
# AA....
# ..ZP..
# ..ZP.C
# ...P.C
#
# OOO..B
# .....B
# ....AA
# ..ZP..
# ..ZP.C
# ...P.C
#
# Initial board configuration
#
# ZZ..O.
# BCDDOE
# BCAAOE
# .P....
# .PF.GG
# .PFQQQ
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, E:100, A:100, P:100, F:100, G:100, Q:100,
# Runtime: 0.48149895668029785 seconds
# Number of moves:  6
# Search path length: 6 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..ZP.B
# AA.P.B
# ...P..
# .....C
# .....C
#
# ...OOO
# ...P.B
# AA.P.B
# ...P..
# ..Z..C
# ..Z..C
#
# ..OOO.
# ...P.B
# AA.P.B
# ...P..
# ..Z..C
# ..Z..C
#
# ..OOOB
# ...P.B
# AA.P..
# ...P..
# ..Z..C
# ..Z..C
#
# ..OOOB
# .....B
# AA....
# ...P..
# ..ZP.C
# ..ZP.C
#
# ..OOOB
# .....B
# ....AA
# ...P..
# ..ZP.C
# ..ZP.C
#
# Initial board configuration
#
# ZZ..O.
# BCDDOE
# BCAAOE
# .P....
# .PF.GG
# .PFQQQ
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, E:100, A:100, P:100, F:100, G:100, Q:100,
# Runtime: 0.4844999313354492 seconds
# Number of moves:  6
# Search path length: 6 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..ZP.B
# AA.P.B
# ...P..
# .....C
# .....C
#
# ...OOO
# ...P.B
# AA.P.B
# ...P..
# ..Z..C
# ..Z..C
#
# .OOO..
# ...P.B
# AA.P.B
# ...P..
# ..Z..C
# ..Z..C
#
# .OOO.B
# ...P.B
# AA.P..
# ...P..
# ..Z..C
# ..Z..C
#
# .OOO.B
# .....B
# AA....
# ...P..
# ..ZP.C
# ..ZP.C
#
# .OOO.B
# .....B
# ....AA
# ...P..
# ..ZP.C
# ..ZP.C
#
# Initial board configuration
#
# ZZ..O.
# BCDDOE
# BCAAOE
# .P....
# .PF.GG
# .PFQQQ
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, E:100, A:100, P:100, F:100, G:100, Q:100,
# Runtime: 0.716996431350708 seconds
# Number of moves:  6
# Search path length: 8 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..ZP.B
# AA.P.B
# ...P..
# .....C
# .....C
#
# ...OOO
# ...P.B
# AA.P.B
# ...P..
# ..Z..C
# ..Z..C
#
# OOO...
# ...P.B
# AA.P.B
# ...P..
# ..Z..C
# ..Z..C
#
# OOO..B
# ...P.B
# AA.P..
# ...P..
# ..Z..C
# ..Z..C
#
# OOO..B
# .....B
# AA....
# ...P..
# ..ZP.C
# ..ZP.C
#
# OOO..B
# .....B
# ....AA
# ...P..
# ..ZP.C
# ..ZP.C
#
# Initial board configuration
#
# ZZ..O.
# BCDDOE
# BCAAOE
# .P....
# .PF.GG
# .PFQQQ
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, E:100, A:100, P:100, F:100, G:100, Q:100,
# Runtime: 2.9279983043670654 seconds
# Number of moves:  6
# Search path length: 31 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# .AAO.Z
# B.....
# B.C...
# ..CPPP
#
# ...O..
# ...O.Z
# .AAO.Z
# B.C...
# B.C...
# ...PPP
#
# ...O..
# ...O.Z
# .AAO.Z
# B.C...
# B.C...
# PPP...
#
# ...O..
# ...O..
# .AAO..
# B.C...
# B.C..Z
# PPP..Z
#
# ......
# ......
# .AA...
# B.CO..
# B.CO.Z
# PPPO.Z
#
# ......
# ......
# ....AA
# B.CO..
# B.CO.Z
# PPPO.Z
#
# Initial board configuration
#
# ..Z.BB
# ..ZC..
# .AACD.
# ....D.
# ..E.FF
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.1719968318939209 seconds
# Number of moves:  6
# Search path length: 2 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# BAAO.Z
# B.....
# ..C...
# ..CPPP
#
# ...O..
# ...O.Z
# BAAO.Z
# B.C...
# ..C...
# ...PPP
#
# ...O..
# ...O.Z
# BAAO.Z
# B.C...
# ..C...
# PPP...
#
# ...O..
# ...O..
# BAAO..
# B.C...
# ..C..Z
# PPP..Z
#
# ......
# ......
# BAA...
# B.CO..
# ..CO.Z
# PPPO.Z
#
# ......
# ......
# B...AA
# B.CO..
# ..CO.Z
# PPPO.Z
#
# Initial board configuration
#
# ..Z.BB
# ..ZC..
# .AACD.
# ....D.
# ..E.FF
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.7934973239898682 seconds
# Number of moves:  6
# Search path length: 2 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ......
# ..C...
# ..CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ..C...
# ..C...
# ...PPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ..C...
# ..C...
# PPP...
#
# ...O..
# B..O..
# BAAO..
# ..C...
# ..C..Z
# PPP..Z
#
# ......
# B.....
# BAA...
# ..CO..
# ..CO.Z
# PPPO.Z
#
# ......
# B.....
# B...AA
# ..CO..
# ..CO.Z
# PPPO.Z
#
# Initial board configuration
#
# ..Z.BB
# ..ZC..
# .AACD.
# ....D.
# ..E.FF
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.4929981231689453 seconds
# Number of moves:  6
# Search path length: 5 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ......
# ..C...
# ..CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ..C...
# ..C...
# ...PPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ..C...
# ..C...
# PPP...
#
# B..O..
# B..O..
# .AAO..
# ..C...
# ..C..Z
# PPP..Z
#
# B.....
# B.....
# .AA...
# ..CO..
# ..CO.Z
# PPPO.Z
#
# B.....
# B.....
# ....AA
# ..CO..
# ..CO.Z
# PPPO.Z
#
# Initial board configuration
#
# ..Z.BB
# ..ZC..
# .AACD.
# ....D.
# ..E.FF
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.4284982681274414 seconds
# Number of moves:  6
# Search path length: 8 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..Z..B
# .AA..B
# ...P..
# ...P.C
# ...P.C
#
# ..ZOOO
# ..Z..B
# ...AAB
# ...P..
# ...P.C
# ...P.C
#
# ...OOO
# ..Z..B
# ..ZAAB
# ...P..
# ...P.C
# ...P.C
#
# ..OOO.
# ..Z..B
# ..ZAAB
# ...P..
# ...P.C
# ...P.C
#
# ..OOOB
# ..Z..B
# ..ZAA.
# ...P..
# ...P.C
# ...P.C
#
# ..OOOB
# ..Z..B
# ..Z.AA
# ...P..
# ...P.C
# ...P.C
#
# Initial board configuration
#
# ...OOO
# ......
# AA.P..
# ZZ.PB.
# .C.PB.
# .C.QQQ
#
# Car Fuel Available: O:100, A:100, P:100, Z:100, B:100, C:100, Q:100,
# Runtime: 0.035497188568115234 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..Z..B
# .AA..B
# ...P..
# ...P.C
# ...P.C
#
# ..ZOOO
# ..Z..B
# ...AAB
# ...P..
# ...P.C
# ...P.C
#
# ...OOO
# ..Z..B
# ..ZAAB
# ...P..
# ...P.C
# ...P.C
#
# .OOO..
# ..Z..B
# ..ZAAB
# ...P..
# ...P.C
# ...P.C
#
# .OOO.B
# ..Z..B
# ..ZAA.
# ...P..
# ...P.C
# ...P.C
#
# .OOO.B
# ..Z..B
# ..Z.AA
# ...P..
# ...P.C
# ...P.C
#
# Initial board configuration
#
# ...OOO
# ......
# AA.P..
# ZZ.PB.
# .C.PB.
# .C.QQQ
#
# Car Fuel Available: O:100, A:100, P:100, Z:100, B:100, C:100, Q:100,
# Runtime: 0.04699969291687012 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..Z..B
# .AA..B
# ...P..
# ...P.C
# ...P.C
#
# ..ZOOO
# ..Z..B
# ...AAB
# ...P..
# ...P.C
# ...P.C
#
# ...OOO
# ..Z..B
# ..ZAAB
# ...P..
# ...P.C
# ...P.C
#
# OOO...
# ..Z..B
# ..ZAAB
# ...P..
# ...P.C
# ...P.C
#
# OOO..B
# ..Z..B
# ..ZAA.
# ...P..
# ...P.C
# ...P.C
#
# OOO..B
# ..Z..B
# ..Z.AA
# ...P..
# ...P.C
# ...P.C
#
# Initial board configuration
#
# ...OOO
# ......
# AA.P..
# ZZ.PB.
# .C.PB.
# .C.QQQ
#
# Car Fuel Available: O:100, A:100, P:100, Z:100, B:100, C:100, Q:100,
# Runtime: 0.058002471923828125 seconds
# Number of moves:  6
# Search path length: 1 states
# ------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# ..ZOOO
# ..Z..B
# .AA..B
# ...P..
# ...P.C
# ...P.C
#
# ..ZOOO
# ..Z..B
# ...AAB
# ...P..
# ...P.C
# ...P.C
#
# ...OOO
# .....B
# ..ZAAB
# ..ZP..
# ...P.C
# ...P.C
#
# ..OOO.
# .....B
# ..ZAAB
# ..ZP..
# ...P.C
# ...P.C
#
# ..OOOB
# .....B
# ..ZAA.
# ..ZP..
# ...P.C
# ...P.C
#
# ..OOOB
# .....B
# ..Z.AA
# ..ZP..
# ...P.C
# ...P.C
#
# Initial board configuration
#
# ...OOO
# ......
# AA.P..
# ZZ.PB.
# .C.PB.
# .C.QQQ
#
# Car Fuel Available: O:100, A:100, P:100, Z:100, B:100, C:100, Q:100,
# Runtime: 0.049500465393066406 seconds
# Number of moves:  6
# ...
# ...O..
# PPPO..
#
# Initial board configuration
#
# ZZBBCD
# OOOECD
# .AAE.F
# ..G..F
# ..GPPP
# ....HH
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, O:100, E:100, A:100, F:100, G:100, P:100, H:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# BAAO.Z
# B.....
# ..C...
# ..CPPP
#
# ...O..
# ...O..
# BAAO..
# B....Z
# ..C..Z
# ..CPPP
#
# ...O..
# ...O..
# BAAO..
# B.C..Z
# ..C..Z
# ...PPP
#
# ...O..
# ...O..
# BAAO..
# B.C..Z
# ..C..Z
# PPP...
#
# ......
# ......
# BAA...
# B.CO.Z
# ..CO.Z
# PPPO..
#
# ......
# ......
# B..AA.
# B.CO.Z
# ..CO.Z
# PPPO..
#
# ......
# ......
# B.CAA.
# B.CO.Z
# ...O.Z
# PPPO..
#
# ......
# ......
# B.C.AA
# B.CO.Z
# ...O.Z
# PPPO..
#
# Initial board configuration
#
# ZZBBCD
# OOOECD
# .AAE.F
# ..G..F
# ..GPPP
# ....HH
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, O:100, E:100, A:100, F:100, G:100, P:100, H:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# ...O.Z
# BAAO.Z
# B.....
# ..C...
# ..CPPP
#
# ...O..
# ...O..
# BAAO..
# B....Z
# ..C..Z
# ..CPPP
#
# ...O..
# ...O..
# BAAO..
# B.C..Z
# ..C..Z
# ...PPP
#
# ...O..
# ...O..
# BAAO..
# B.C..Z
# ..C..Z
# PPP...
#
# ......
# ......
# BAA...
# B.CO.Z
# ..CO.Z
# PPPO..
#
# ......
# ......
# B..AA.
# B.CO.Z
# ..CO.Z
# PPPO..
#
# ......
# ..C...
# B.CAA.
# B..O.Z
# ...O.Z
# PPPO..
#
# ......
# ..C...
# B.C.AA
# B..O.Z
# ...O.Z
# PPPO..
#
# Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ......
# ..C...
# ..CPPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ......
# ..C...
# ..CPPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ..C...
# ..C...
# ...PPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ..C...
# ..C...
# PPP...
#
# .....Z
# B....Z
# BAA...
# ..CO..
# ..CO..
# PPPO..
#
# .....Z
# B....Z
# B..AA.
# ..CO..
# ..CO..
# PPPO..
#
# .....Z
# B....Z
# B.CAA.
# ..CO..
# ...O..
# PPPO..
#
# .....Z
# B....Z
# B.C.AA
# ..CO..
# ...O..
# PPPO..
#
# Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ......
# ..C...
# ..CPPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ......
# ..C...
# ..CPPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ..C...
# ..C...
# ...PPP
#
# ...O.Z
# B..O.Z
# BAAO..
# ..C...
# ..C...
# PPP...
#
# .....Z
# B....Z
# BAA...
# ..CO..
# ..CO..
# PPPO..
#
# .....Z
# B....Z
# B..AA.
# ..CO..
# ..CO..
# PPPO..
#
# .....Z
# B.C..Z
# B.CAA.
# ...O..
# ...O..
# PPPO..
#
# .....Z
# B.C..Z
# B.C.AA
# ...O..
# ...O..
# PPPO..
#
# Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ......
# ..C...
# ..CPPP
#
# ...O..
# B..O..
# BAAO..
# .....Z
# ..C..Z
# ..CPPP
#
# ...O..
# B..O..
# BAAO..
# ..C..Z
# ..C..Z
# ...PPP
#
# ...O..
# B..O..
# BAAO..
# ..C..Z
# ..C..Z
# PPP...
#
# ......
# B.....
# BAA...
# ..CO.Z
# ..CO.Z
# PPPO..
#
# ......
# B.....
# B..AA.
# ..CO.Z
# ..CO.Z
# PPPO..
#
# ......
# B.....
# B.CAA.
# ..CO.Z
# ...O.Z
# PPPO..
#
# ......
# B.....
# B.C.AA
# ..CO.Z
# ...O.Z
# PPPO..
#
# Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# ...O..
# B..O.Z
# BAAO.Z
# ......
# ..C...
# ..CPPP
#
# ...O..
# B..O..
# BAAO..
# .....Z
# ..C..Z
# ..CPPP
#
# ...O..
# B..O..
# BAAO..
# ..C..Z
# ..C..Z
# ...PPP
#
# ...O..
# B..O..
# BAAO..
# ..C..Z
# ..C..Z
# PPP...
#
# ......
# B.....
# BAA...
# ..CO.Z
# ..CO.Z
# PPPO..
#
# ......
# B.....
# B..AA.
# ..CO.Z
# ..CO.Z
# PPPO..
#
# ......
# B.C...
# B.CAA.
# ...O.Z
# ...O.Z
# PPPO..
#
# ......
# B.C...
# B.C.AA
# ...O.Z
# ...O.Z
# PPPO..
#
# Initial board configuration
#
# .ZBBC.
# .Z..C.
# AAD.O.
# ..D.O.
# ..E.O.
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ......
# ..C...
# ..CPPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ......
# ..C...
# ..CPPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ..C...
# ..C...
# ...PPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ..C...
# ..C...
# PPP...
#
# B....Z
# B....Z
# .AA...
# ..CO..
# ..CO..
# PPPO..
#
# B....Z
# B....Z
# ...AA.
# ..CO..
# ..CO..
# PPPO..
#
# B....Z
# B....Z
# ..CAA.
# ..CO..
# ...O..
# PPPO..
#
# B....Z
# B....Z
# ..C.AA
# ..CO..
# ...O..
# PPPO..
#
# Initial board configuration
#
# .ZBBC.
# .Z..C.
# AAD.O.
# ..D.O.
# ..E.O.
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ......
# ..C...
# ..CPPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ......
# ..C...
# ..CPPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ..C...
# ..C...
# ...PPP
#
# B..O.Z
# B..O.Z
# .AAO..
# ..C...
# ..C...
# PPP...
#
# B....Z
# B....Z
# .AA...
# ..CO..
# ..CO..
# PPPO..
#
# B....Z
# B....Z
# ...AA.
# ..CO..
# ..CO..
# PPPO..
#
# B....Z
# B.C..Z
# ..CAA.
# ...O..
# ...O..
# PPPO..
#
# B....Z
# B.C..Z
# ..C.AA
# ...O..
# ...O..
# PPPO..
#
# Initial board configuration
#
# .ZBBC.
# .Z..C.
# AAD.O.
# ..D.O.
# ..E.O.
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ......
# ..C...
# ..CPPP
#
# B..O..
# B..O..
# .AAO..
# .....Z
# ..C..Z
# ..CPPP
#
# B..O..
# B..O..
# .AAO..
# ..C..Z
# ..C..Z
# ...PPP
#
# B..O..
# B..O..
# .AAO..
# ..C..Z
# ..C..Z
# PPP...
#
# B.....
# B.....
# .AA...
# ..CO.Z
# ..CO.Z
# PPPO..
#
# B.....
# B.....
# ...AA.
# ..CO.Z
# ..CO.Z
# PPPO..
#
# B.....
# B.....
# ..CAA.
# ..CO.Z
# ...O.Z
# PPPO..
#
# B.....
# B.....
# ..C.AA
# ..CO.Z
# ...O.Z
# PPPO..
#
# Initial board configuration
#
# .ZBBC.
# .Z..C.
# AAD.O.
# ..D.O.
# ..E.O.
# ..E...
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, O:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# B..O..
# B..O.Z
# .AAO.Z
# ......
# ..C...
# ..CPPP
#
# B..O..
# B..O..
# .AAO..
# .....Z
# ..C..Z
# ..CPPP
#
# B..O..
# B..O..
# .AAO..
# ..C..Z
# ..C..Z
# ...PPP
#
# B..O..
# B..O..
# .AAO..
# ..C..Z
# ..C..Z
# PPP...
#
# B.....
# B.....
# .AA...
# ..CO.Z
# ..CO.Z
# PPPO..
#
# B.....
# B.....
# ...AA.
# ..CO.Z
# ..CO.Z
# PPPO..
#
# B.....
# B.C...
# ..CAA.
# ...O.Z
# ...O.Z
# PPPO..
#
# B.....
# B.C...
# ..C.AA
# ...O.Z
# ...O.Z
# PPPO..
#
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 4.564498424530029 seconds
# Number of moves:  8
# Search path length: 32 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# Z.OOOD
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# Z.OOOD
# Z.BC.D
# AABC..
# PPP...
# ......
# ......
#
# Z.OOOD
# Z.B..D
# AAB...
# PPP...
# ...C..
# ...C..
#
# Z.OOOD
# Z.B..D
# AAB...
# ...PPP
# ...C..
# ...C..
#
# Z.OOOD
# Z....D
# AA....
# ...PPP
# ..BC..
# ..BC..
#
# Z.OOOD
# Z....D
# AA....
# ..PPP.
# ..BC..
# ..BC..
#
# Z.OOOD
# Z....D
# ....AA
# ..PPP.
# ..BC..
# ..BC..
#
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# Z.OOOD
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# Z.OOOD
# Z.BC.D
# AABC..
# PPP...
# ......
# ......
#
# Z.OOOD
# Z.B..D
# AAB...
# PPP...
# ...C..
# ...C..
#
# Z.OOOD
# Z.B..D
# AAB...
# ...PPP
# ...C..
# ...C..
#
# Z.OOOD
# Z....D
# AA....
# ...PPP
# ..BC..
# ..BC..
#
# Z.OOOD
# Z....D
# AA....
# .PPP..
# ..BC..
# ..BC..
#
# Z.OOOD
# Z....D
# ....AA
# .PPP..
# ..BC..
# ..BC..
#
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 4.340999364852905 seconds
# Number of moves:  8
# Search path length: 37 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPPD
# .....D
# ......
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPPD
# .....D
# ......
#
# Z.BOOO
# Z.BC..
# AA.C..
# ..PPPD
# .....D
# ......
#
# Z.BOOO
# Z.BC..
# AA.C..
# PPP..D
# .....D
# ......
#
# Z.BOOO
# Z.B...
# AA....
# PPP..D
# ...C.D
# ...C..
#
# Z.BOOO
# Z.B...
# AA....
# .PPP.D
# ...C.D
# ...C..
#
# Z.BOOO
# Z.B...
# ....AA
# .PPP.D
# ...C.D
# ...C..
#
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPPD
# .....D
# ......
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPPD
# .....D
# ......
#
# Z.BOOO
# Z.BC..
# AA.C..
# ..PPPD
# .....D
# ......
#
# Z.BOOO
# Z.BC..
# AA.C..
# PPP..D
# .....D
# ......
#
# Z.BOOO
# Z.B...
# AA....
# PPP..D
# ...C.D
# ...C..
#
# Z.BOOO
# Z.B...
# AA....
# ..PPPD
# ...C.D
# ...C..
#
# Z.BOOO
# Z.B...
# ....AA
# ..PPPD
# ...C.D
# ...C..
#
# Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:100, P:100, Q:100, A:100, Z:100, R:100, B:100,
# Runtime: 3.4389970302581787 seconds
# Number of moves:  8
# Search path length: 26 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z.BOOO
# Z.BC..
# AA.C..
# ..PPP.
# .....D
# .....D
#
# Z.BOOO
# Z.BC..
# AA.C..
# PPP...
# .....D
# .....D
#
# Z.BOOO
# Z.B...
# AA....
# PPP...
# ...C.D
# ...C.D
#
# Z.BOOO
# Z.B...
# AA....
# .PPP..
# ...C.D
# ...C.D
#
# Z.BOOO
# Z.B...
# ....AA
# .PPP..
# ...C.D
# ...C.D
#
# Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:100, P:100, Q:100, A:100, Z:100, R:100, B:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z.BOOO
# Z.BC..
# AA.C..
# ..PPP.
# .....D
# .....D
#
# Z.BOOO
# Z.BC..
# AA.C..
# PPP...
# .....D
# .....D
#
# Z.BOOO
# Z.B...
# AA....
# PPP...
# ...C.D
# ...C.D
#
# Z.BOOO
# Z.B...
# AA....
# ..PPP.
# ...C.D
# ...C.D
#
# Z.BOOO
# Z.B...
# ....AA
# ..PPP.
# ...C.D
# ...C.D
#
# Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:100, P:100, Q:100, A:100, Z:100, R:100, B:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z.BOOO
# Z.BC..
# AA.C..
# ..PPP.
# .....D
# .....D
#
# Z.BOOO
# Z.BC..
# AA.C..
# PPP...
# .....D
# .....D
#
# Z.BOOO
# Z.B...
# AA....
# PPP...
# ...C.D
# ...C.D
#
# Z.BOOO
# Z.B...
# AA....
# ...PPP
# ...C.D
# ...C.D
#
# Z.BOOO
# Z.B...
# ....AA
# ...PPP
# ...C.D
# ...C.D
#
# Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:100, P:100, Q:100, A:100, Z:100, R:100, B:100,
# Runtime: 0.4825167655944824 seconds
# Number of moves:  8
# Search path length: 3 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# PPP...
# .....D
# .....D
#
# Z..OOO
# Z.B...
# AAB...
# PPP...
# ...C.D
# ...C.D
#
# Z..OOO
# Z.B...
# AAB...
# ...PPP
# ...C.D
# ...C.D
#
# Z..OOO
# Z.....
# AA....
# ..BPPP
# ..BC.D
# ...C.D
#
# Z..OOO
# Z.....
# ....AA
# ..BPPP
# ..BC.D
# ...C.D
#
# Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100,
# Runtime: 0.6500005722045898 seconds
# Number of moves:  8
# Search path length: 3 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# PPP...
# .....D
# .....D
#
# Z..OOO
# Z.B...
# AAB...
# PPP...
# ...C.D
# ...C.D
#
# Z..OOO
# Z.B...
# AAB...
# ...PPP
# ...C.D
# ...C.D
#
# Z..OOO
# Z.....
# AA....
# ...PPP
# ..BC.D
# ..BC.D
#
# Z..OOO
# Z.....
# ....AA
# ...PPP
# ..BC.D
# ..BC.D
#
# Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100,
# Runtime: 0.7149999141693115 seconds
# Number of moves:  8
# Search path length: 6 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ...PPP
# .....D
# .....D
#
# Z..OOO
# Z..C..
# AA.C..
# ...PPP
# ..B..D
# ..B..D
#
# Z..OOO
# Z..C..
# AA.C..
# PPP...
# ..B..D
# ..B..D
#
# Z..OOO
# Z.....
# AA....
# PPPC..
# ..BC.D
# ..B..D
#
# Z..OOO
# Z.....
# ....AA
# PPPC..
# ..BC.D
# ..B..D
#
# Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100,
# Runtime: 0.3105003833770752 seconds
# Number of moves:  8
# Search path length: 2 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# Z..OOO
# Z.BC..
# AABC..
# ...PPP
# .....D
# .....D
#
# Z..OOO
# Z..C..
# AA.C..
# ...PPP
# ..B..D
# ..B..D
#
# Z..OOO
# Z..C..
# AA.C..
# PPP...
# ..B..D
# ..B..D
#
# Z..OOO
# Z.....
# AA....
# PPP...
# ..BC.D
# ..BC.D
#
# Z..OOO
# Z.....
# ....AA
# PPP...
# ..BC.D
# ..BC.D
#
# Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100,
# Runtime: 4.4899985790252686 seconds
# Number of moves:  8
# Search path length: 32 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# ZOOO..
# Z.BC..
# AABC..
# PPP...
# .....D
# .....D
#
# ZOOO..
# Z.B...
# AAB...
# PPP...
# ...C.D
# ...C.D
#
# ZOOO..
# Z.B...
# AAB...
# ...PPP
# ...C.D
# ...C.D
#
# ZOOO..
# Z.....
# AA....
# ...PPP
# ..BC.D
# ..BC.D
#
# ZOOO..
# Z.....
# AA....
# ..PPP.
# ..BC.D
# ..BC.D
#
# ZOOO..
# Z.....
# ....AA
# ..PPP.
# ..BC.D
# ..BC.D
#
# Initial board configuration
#
# ..O.ZZ
# ..O.BB
# AAO..C
# .....C
# ...DEE
# ...D..
#
# Car Fuel Available: O:100, Z:100, B:100, A:100, C:100, D:100, E:100,
# Runtime: 0.0 seconds
# Number of moves:  8
# Search path length: 0 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO..
# Z.BC..
# AABC..
# ..PPP.
# .....D
# .....D
#
# ZOOO..
# Z.BC..
# AABC..
# PPP...
# .....D
# .....D
#
# ZOOO..
# Z.B...
# AAB...
# PPP...
# ...C.D
# ...C.D
#
# ZOOO..
# Z.B...
# AAB...
# ...PPP
# ...C.D
# ...C.D
#
# ZOOO..
# Z.....
# AA....
# ...PPP
# ..BC.D
# ..BC.D
#
# ZOOO..
# Z.....
# AA....
# .PPP..
# ..BC.D
# ..BC.D
#
# ZOOO..
# Z.....
# ....AA
# .PPP..
# ..BC.D
# ..BC.D
#
# Initial board configuration
#
# ..O.ZZ
# ..O.BB
# AAO..C
# .....C
# ...DEE
# ...D..
#
# Car Fuel Available: O:100, Z:100, B:100, A:100, C:100, D:100, E:100,
# Runtime: 7.9385011196136475 seconds
# Number of moves:  8
# Search path length: 61 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# PPP...
# ......
# ......
#
# ZOOO.D
# Z.B..D
# AAB...
# PPP...
# ...C..
# ...C..
#
# ZOOO.D
# Z.B..D
# AAB...
# ...PPP
# ...C..
# ...C..
#
# ZOOO.D
# Z....D
# AA....
# ..BPPP
# ..BC..
# ...C..
#
# ZOOO.D
# Z....D
# .AA...
# ..BPPP
# ..BC..
# ...C..
#
# .OOO.D
# Z....D
# ZAA...
# ..BPPP
# ..BC..
# ...C..
#
# .OOO.D
# Z....D
# Z...AA
# ..BPPP
# ..BC..
# ...C..
#
# Initial board configuration
#
# ..O.ZZ
# ..O.BB
# AAO..C
# .....C
# ...DEE
# ...D..
#
# Car Fuel Available: O:100, Z:100, B:100, A:100, C:100, D:100, E:100,
# Runtime: 0.10149693489074707 seconds
# Number of moves:  8
# Search path length: 1 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# PPP...
# ......
# ......
#
# ZOOO.D
# Z.B..D
# AAB...
# PPP...
# ...C..
# ...C..
#
# ZOOO.D
# Z.B..D
# AAB...
# ...PPP
# ...C..
# ...C..
#
# ZOOO.D
# Z....D
# AA....
# ..BPPP
# ..BC..
# ...C..
#
# ZOOO.D
# Z....D
# .AA...
# ..BPPP
# ..BC..
# ...C..
#
# .OOO.D
# .....D
# ZAA...
# Z.BPPP
# ..BC..
# ...C..
#
# .OOO.D
# .....D
# Z...AA
# Z.BPPP
# ..BC..
# ...C..
#
# Initial board configuration
#
# ..O.ZZ
# ..O.BB
# AAO..C
# .....C
# ...DEE
# ...D..
#
# Car Fuel Available: O:100, Z:100, B:100, A:100, C:100, D:100, E:100,
# Runtime: 0.26000070571899414 seconds
# Number of moves:  8
# Search path length: 2 states
# ------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# ..PPP.
# ......
# ......
#
# ZOOO.D
# Z.BC.D
# AABC..
# PPP...
# ......
# ......
#
# ZOOO.D
# Z.B..D
# AAB...
# PPP...
# ...C..
# ...C..
#
# ZOOO.D
# Z.B..D
# AAB...
# ...PPP
# ...C..
# ...C..
#
# ZOOO.D
# Z....D
# AA....
# ..BPPP
# ..BC..
# ...C..
#
# ZOOO.D
# Z....D
# .AA...
# ..BPPP
# ..BC..
# ...C..
#
# .OOO.D
# .....D
# .AA...
# Z.BPPP
# Z.BC..
# ...C..
#
# .OOO.D
# .....D
# ....AA
# Z.BPPP
# Z.BC..
# ...C..
