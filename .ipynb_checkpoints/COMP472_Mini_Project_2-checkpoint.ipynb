# %% [markdown]
# # Imports

# %%
# IMPORTS
import copy
import numpy as np
from enum import Enum
import bisect 
import time

# %% [markdown]
# # CLASS INITIALIZATIONS

# %%
class Direction(Enum):
  HORIZONTAL = 1
  VERTICAL = 2

class Coordinate():
  def __init__(self, X, Y):
    self.X = X 
    self.Y = Y
  # Primarily for testing to see if Coordinate works
  def __str__(self):
    return "(" + str(self.X) + ", " + str(self.Y) + ")"

#
# CAR
# 

class Car(object):
  def __init__(self, letter, coordinate, fuel):
    self.letter = letter  # Remember that A is the most important
    self.coordinates = []
    self.coordinates.append(coordinate)
    self.fuel = int(fuel)

  def isA(self):
    return self.letter == 'A'

  def move(self, amt):
    if self.direction == Direction.HORIZONTAL:
      for c in self.coordinates:
        c.Y += amt
    else:
      for c in self.coordinates:
        c.X += amt
    self.fuel -= abs(amt)
  
  def canMove(self):
    return self.fuel > 0

  def compareLetters(self, letter):
    return self.letter == letter

  def addCoordinate(self, newCoord):
    self.coordinates.append(newCoord)
    # Update direction
    # L-R (Horizontal)
    if self.coordinates[0].X == newCoord.X and self.coordinates[0].Y != newCoord.Y:
      self.direction = Direction.HORIZONTAL
    # U-D (Vertical)
    else:
      self.direction = Direction.VERTICAL

  def getLetter(self):
    return self.letter; 

  # Primarily for testing to see if Car works
  def __str__(self):
    s = self.letter + " -> ";
    for i in self.coordinates:
      s += str(i)
    return s + " | " + str(self.fuel) + " | " + str(self.direction)

  @staticmethod
  def create(letter, coordinates, fuel):
    return Car(letter, coordinates, fuel)


#
# BOARD
# 

class Board(object):
  def __init__(self, cars):
    self.grid = [['.' for i in range(6)] for j in range(6)]
    self.size = {'X': 6, 'Y': 6}
    self.cars = []
    for car in cars:  
      c = car
      self.cars.append(copy.deepcopy(c));
      for coord in c.coordinates:
        self.grid[coord.X][coord.Y] = car.letter
        
  def __eq__(self, obj):
        return self.grid == obj.grid

  def findCarPaths(self, car):
    if car.canMove():
      fwd = self.checkPathForward(car)
      bwd = self.checkPathBackward(car)
      carPath = bwd + fwd
    else:
      carPath = []
    return carPath
  
  def moveCar(self, carLetter, amt):
    for car in self.cars: 
      if car.letter == carLetter:
        for coord in car.coordinates:
          #print(coord)
          self.grid[coord.X][coord.Y] = "."
        car.move(amt)
        for coord in car.coordinates:
          #print(coord)
          self.grid[coord.X][coord.Y] = carLetter
        
        # Is this a regular car that just left?
        if car.letter == self.grid[2][5] and car.direction == Direction.HORIZONTAL and car.letter != "A":
          for coord in car.coordinates:
            self.grid[coord.X][coord.Y] = "."
          self.cars.remove(car)  
        
        
        direction="";
        if(amt<0 and car.direction==Direction.VERTICAL):
            direction="up"
        if(amt>0 and car.direction==Direction.VERTICAL):
            direction="down"
        if(amt<0 and car.direction==Direction.HORIZONTAL):
            direction="left"
        if(amt>0 and car.direction==Direction.HORIZONTAL):
            direction="right"        
        #returns the move performed
        return((carLetter, direction, abs(amt), car.fuel, self.stringLine()))
        
  # ......
  # ...AA. (1,3)(1,4)
  # ......
  # startPoint = 4
  # range(5,6) -> 5
  # next gridPos = (1,5)
  # append -> 5 - 4 = 1

  # ...D.. (0,3)
  # ...D.. (1,3)
  # ......
  # startPoint = 1
  # range(2,6) -> 2, 3, 4, 5
  # next gridPos = (2,3)
  # append -> 2 - 1 = 1
  def checkPathForward(self, car):
    dir = car.direction
    lastCoord = car.coordinates[len(car.coordinates)-1]
    if dir == Direction.HORIZONTAL:
      startPoint = lastCoord.Y
    else:
      startPoint = lastCoord.X

    possibleMoves = []
    for i in range(startPoint+1, 6):
        #fuel req
      if(car.fuel < i-startPoint):
        continue;
      # Find next position to check    
      if dir == Direction.HORIZONTAL:
        gridPos = self.grid[lastCoord.X][i] 
      else:
        gridPos = self.grid[i][lastCoord.Y]

      # If there's an open position, add and continue
      # Else, there is something blocking the way and there's no way to continue any more
      if gridPos == ".":
        possibleMoves.append(i-startPoint)
      else:
        break;

    return possibleMoves

  # ......
  # ...AA. (1,3)(1,4)
  # ......
  # startPoint = 3
  # range(3,0,-1) -> 3, 2, 1
  # i = i - 1 -> 2, 1, 0
  # next gridPos = (1,2)
  # append -> 2 - 3 = -1

  # ...D.. (0,3)
  # ...D.. (1,3)
  # ......
  # startPoint = 0
  # range(0,0) -> NONE
  # next gridPos = NONE
  def checkPathBackward(self, car):
    dir = car.direction
    lastCoord = car.coordinates[0]
    if dir == Direction.HORIZONTAL:
      startPoint = lastCoord.Y
    else:
      startPoint = lastCoord.X

    possibleMoves = []
    for i in range(startPoint, 0, -1):
      if (car.fuel <= (startPoint-i)):
        continue
      # Find next position to check
      if dir == Direction.HORIZONTAL:
        gridPos = self.grid[lastCoord.X][i-1] 
      else:
        gridPos = self.grid[i-1][lastCoord.Y]

      # If there's an open position, add and continue
      # Else, there is something blocking the way and there's no way to continue any more
      if gridPos == ".":
        possibleMoves.append(i-startPoint-1)
      else:
        break;

    return possibleMoves

  def winConditionMet(self):
    if self.grid[2][5] == "A":
      return True      
    return False

  def __str__(self): 
    s = ""
    for x in range(6):
      for y in range(6):
        s += self.grid[x][y]
      s += "\n" 
    return s

  def stringLine(self):
    s = ""
    for x in range(6):
      for y in range(6):
        s += self.grid[x][y]
    return s

  def AllUsedCars(self):
    s = ""
    for c in cars:
      if(c.fuel < 100):
        s += c.getLetter + " " + c.fuel + " ";
    return s


  #Heuristic definitions:

  #h1 = The number of blocking vehicles
  def h1(self):
        count = 0
        last = " "
        for i in range(6):
            e = self.grid[2][5-i]
            if e == "A":
                break
            elif e == last:
                continue
            elif e != ".":
                count += 1
                last = e
        return count
  
  #h2 = The number of blocked positions
  def h2(self):
        count = 0
        for i in range(6):
            e = self.grid[2][5-i]
            if e == "A":
                break
            elif e != ".":
                count += 1
        return count
    
  #h3 = The number of blocking vehicles (h1) multiplied by a constant
  def h3(self, constant):
        return self.h1()*constant
    
  #h4 = 
  def h4(self):
        count = 0
        last = " "
        blocked = []
        for i in range(6):
            e = self.grid[2][5-i]
            if e == "A":
                break
            elif e == last:
                continue
            elif e != ".":
                count += 1
                last = e
                #Check if car is horizontal by looking at the next slot in the grid
                if self.grid[2][5-i-1] == e:
                    continue
                #If the car is not horizontal, we count how many squares block it in both directions
                else:
                    last2 = " "
                    up = 0
                    for j in range(2):
                        if self.grid[2-j-1][5-i] == e or self.grid[2-j-1][5-i] == "." or self.grid[2-j-1][5-i] == last2:
                            continue
                        else:
                            up += 1
                            last2 = self.grid[2-j-1][5-i]
                    if up == 0:
                        continue
                    last2 = " "
                    down = 0
                    for j in range(3):
                        if self.grid[2+j+1][5-i] == e or self.grid[2+j+1][5-i] == "." or self.grid[2+j+1][5-i] == last2:
                            continue
                        else:
                            down += 1
                            last2 = self.grid[2+j+1][5-i]
                    if down == 0:
                        continue
                    blocked.append(min(up, down))
                        
        if blocked:
            return count + max(blocked)
        else:
            return count
                    
                
        
        if self.grid[2][5] != "." and self.grid[2][5] != "A":
            return 1
        else:
            return 0

# %% [markdown]
# # Extracting Data From Sample-input.txt

# %%
demos = []
demoFuels = []

with open('sample-input-50.txt') as f:
    for line in f:
      if not line.startswith(('#', '\n')):
        in_arr = np.array([line.strip()])
        data = np.char.split(in_arr)[0]
        demos.append(data)
f.close()

print(demos)
# Out:
# [['Z.BOOOZ.B....AAC...D.C...DPPPE.....E'], ['....ZZ....O..AA.OB....OB.....C...DDC'], ['....Z.....Z.AA.BC..O.BC..ODDEE.O....'], ['..ZOOO..ZP.B.AAP.B...P.......C.....C'], ['ZZ..O...BBOC..AAOC...DD...EFF...E...'], ['...O.....O.Z.AAO.Z......B.C...B.CPPP'], ['.....Z..OOOZAA.B.C...B.C.DDPPP......'], ['ZOOO..Z.BC.DAABC.D..PPP.............'], ['ZZBBCC....DE..AADE..O.....OFGG..OF..'], ['ZZ.BCCOOOB.D..EAADFFEGGHIJJ..HI...KK'], ['...ZZ....BCCAA.B.D...E.D...EFF......'], ['OZBBCCOZ.DEEOAADF.GGH.FP..HIIP.JJKKP'], ['OZBCCDOZBEFDOAAEF....GHHII.G..JJPPP.'], ['Z.BOOOZ.BCDDPAACEFPG..EFPGQQQH.....H'], ['...OOO....P...AAP..QQQP...ZBCC..ZB..'], ['Z.O...Z.O...AAO..........BBC.DPPPC.D'], ['..OPPP..OZ.QAAOZBQ...RBQ.CCRD....RD.'], ['ZZ..O.BCDDOEBCAAOE.P.....PF.GG.PFQQQ'], ['..Z.BB..ZC...AACD.....D...E.FF..E...'], ['...OOO......AA.P..ZZ.PB..C.PB..C.QQQ'], ['..ZBCC..ZB....AADE....DE.FFOOO......'], ['.ZZ.BB...CC.AA.OD....OD....OEE......'], ['OOO.P...ZZP...AAP.......BBC.DD..C...'], ['ZBBCDDZ..CEEAA..O..PPPOF..G.OFHHG.II'], ['.ZZOOO.....BCC.AAB..P.....PQQQ..P...'], ['.ZZ..OBBPPPOQ.CAAOQ.C...Q..DEEFF.DGG'], ['...OZ...BOZ.AABOCD....CD........EE..'], ['...OOO....ZZBBPAAC..P..C..PQQQ......'], ['ZBB.C.Z.D.COAAD..O.PQEEO.PQFGG.PQFHH'], ['..O.....OPPPAAOQ.Z...Q.Z.BBQCC......'], ['Z.OOO.Z..BCCAA.BDP.QQQDP.E...P.EFFGG'], ['.......OOO.ZAAB.CZ.PB.C..PDD...P....'], ['Z.B.CCZ.B...AAD..EFFD..EOOO.GH....GH'], ['...O...ZZO.B.AAO.B..C.....CPPP..DD..'], ['..OZ....OZ.BAAOC.B...C.....DD..EE...'], ['..ZZOP.QQQOP.BAAOP.B.C.....CDD...RRR'], ['ZZOOO.....B...AAB...C.DD..C.EE.PPP..'], ['..OP....OP..AAOP....ZZ...B..C..BDDC.'], ['.OOOZZ...BC.AA.BC....PPP............', 'O3', 'Z3', 'B3', 'C3', 'A3', 'O3', 'D3', 'E3'], ['..ZZO.....O.AA..OB.....BC.DDEEC.....', 'Z21', 'O9', 'A5'], ['..Z..O..Z..OAAB..O.CBPPPDC.EFFDGGE..', 'O12', 'G14', 'E8'], ['Z..BCCZODB...ODAAE.OPPPEQQQ.FG....FG', 'Z19', 'C5', 'A5'], ['.ZZOOO....B.AA..B...CCDD...PPP......', 'Z2'], ['ZZBBCDOOOECD.AAE.F..G..F..GPPP....HH', 'Z20', 'G2'], ['.ZZBCC...B....AAD.....D..OOOE.....E.', 'B17', 'A6'], ['.ZBBC..Z..C.AAD.O...D.O...E.O...E...', 'A7', 'O3'], ['....O.ZB..OCZBAAOC.DPEFF.DPE....P...', 'O5', 'Z6'], ['OOO.PQ....PQ..AAPQ........ZRRR..ZBB.', 'O10', 'P10', 'Q10', 'A10', 'Z4', 'B1'], ['.ZZ.....BC..AABC...DD...............', 'Z2', 'B2', 'C2', 'D2'], ['..O.ZZ..O.BBAAO..C.....C...DEE...D..', 'A3']]

# %% [markdown]
# # Setting the boards up

# %%
boards = []
for data in demos:
  # Seperate Grid Data from the Fuel Parameters
  grid = data[0];
  fuels = []
  if len(data) > 1:
    fuels.append(data[1:])

  cars = []
  for row in range(6):
    for col in range(6):
      current = grid[row*6 + col];
      
      # If Unique: Create a car and append
      # If Not Unique: Concat to same letter
      if current == ".":
        continue

      unique = True
      for c in cars:
        if c.compareLetters(current):
          c.addCoordinate(Coordinate(row,col))
          unique = False

      if unique:
        # Now check if there's a unique fuel amount or if its the default 100
        fuelAmt = 100
        if len(fuels) > 0:
          for f in fuels[0]:
            if current == f[0]:
              fuelAmt = f[1:]

        cars.append(Car.create(current, Coordinate(row,col), fuelAmt));

  # Checking if all cars were made properly
  print("CARS: ")
  print("--------")
  for c in cars:
    print(c)
  print()
  
  board = Board(cars)
  # Checking if all boards were made properly
  print("BOARD: ")
  print("--------")
  print(board)
  print()

  boards.append(board)


  for b in boards:
    for c in b.cars:
      print(c)
    print()
# Out:
# CARS:
# --------
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# BOARD:
# --------
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# CARS:
# --------
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# BOARD:
# --------
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# CARS:
# --------
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# O -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# O -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 0)(1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# E -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# F -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# H -> (3, 5)(4, 5) | 100 | Direction.VERTICAL
# I -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# J -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# O -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 0)(1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# E -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# F -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# H -> (3, 5)(4, 5) | 100 | Direction.VERTICAL
# I -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# J -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# B -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# C -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# E -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# O -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 0)(1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# E -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# F -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# H -> (3, 5)(4, 5) | 100 | Direction.VERTICAL
# I -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# J -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# B -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# C -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# E -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# E -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# F -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# G -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# H -> (3, 2)(4, 2) | 100 | Direction.VERTICAL
# P -> (3, 5)(4, 5)(5, 5) | 100 | Direction.VERTICAL
# I -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# J -> (5, 1)(5, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# O -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 0)(1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# E -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# F -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# H -> (3, 5)(4, 5) | 100 | Direction.VERTICAL
# I -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# J -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# B -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# C -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# E -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# E -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# F -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# G -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# H -> (3, 2)(4, 2) | 100 | Direction.VERTICAL
# P -> (3, 5)(4, 5)(5, 5) | 100 | Direction.VERTICAL
# I -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# J -> (5, 1)(5, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# C -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# D -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# E -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# F -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# H -> (3, 4)(3, 5) | 100 | Direction.HORIZONTAL
# I -> (4, 0)(4, 1) | 100 | Direction.HORIZONTAL
# J -> (5, 0)(5, 1) | 100 | Direction.HORIZONTAL
# P -> (5, 2)(5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# O -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 0)(1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# E -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# F -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# H -> (3, 5)(4, 5) | 100 | Direction.VERTICAL
# I -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# J -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# B -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# C -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# E -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# E -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# F -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# G -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# H -> (3, 2)(4, 2) | 100 | Direction.VERTICAL
# P -> (3, 5)(4, 5)(5, 5) | 100 | Direction.VERTICAL
# I -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# J -> (5, 1)(5, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# C -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# D -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# E -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# F -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# H -> (3, 4)(3, 5) | 100 | Direction.HORIZONTAL
# I -> (4, 0)(4, 1) | 100 | Direction.HORIZONTAL
# J -> (5, 0)(5, 1) | 100 | Direction.HORIZONTAL
# P -> (5, 2)(5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# CARS:
# --------
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# P -> (2, 0)(3, 0)(4, 0) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# E -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# F -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# G -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# Q -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# H -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# BOARD:
# --------
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# O -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 0)(1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# E -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# F -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# H -> (3, 5)(4, 5) | 100 | Direction.VERTICAL
# I -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# J -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# B -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# C -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# E -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# E -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# F -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# G -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# H -> (3, 2)(4, 2) | 100 | Direction.VERTICAL
# P -> (3, 5)(4, 5)(5, 5) | 100 | Direction.VERTICAL
# I -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# J -> (5, 1)(5, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# C -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# D -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# E -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# F -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# H -> (3, 4)(3, 5) | 100 | Direction.HORIZONTAL
# I -> (4, 0)(4, 1) | 100 | Direction.HORIZONTAL
# J -> (5, 0)(5, 1) | 100 | Direction.HORIZONTAL
# P -> (5, 2)(5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# P -> (2, 0)(3, 0)(4, 0) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# E -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# F -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# G -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# Q -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# H -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# CARS:
# --------
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# Q -> (3, 1)(3, 2)(3, 3) | 100 | Direction.HORIZONTAL
# Z -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# B -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# C -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# BOARD:
# --------
# ...OOO
# ....P.
# ..AAP.
# .QQQP.
# ..ZBCC
# ..ZB..
#
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# O -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# D -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 3)(2, 3)(3, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# P -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 1)(0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
#
# ...
# C -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# E -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# D -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# E -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# F -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# G -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# H -> (3, 2)(4, 2) | 100 | Direction.VERTICAL
# P -> (3, 5)(4, 5)(5, 5) | 100 | Direction.VERTICAL
# I -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# J -> (5, 1)(5, 2) | 100 | Direction.HORIZONTAL
# K -> (5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(1, 0)(2, 0) | 100 | Direction.VERTICAL
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# C -> (0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# D -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# E -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# F -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# G -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# H -> (3, 4)(3, 5) | 100 | Direction.HORIZONTAL
# I -> (4, 0)(4, 1) | 100 | Direction.HORIZONTAL
# J -> (5, 0)(5, 1) | 100 | Direction.HORIZONTAL
# P -> (5, 2)(5, 3)(5, 4) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# D -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# P -> (2, 0)(3, 0)(4, 0) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# E -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# F -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# G -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# Q -> (4, 2)(4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# H -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# P -> (1, 4)(2, 4)(3, 4) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# Q -> (3, 1)(3, 2)(3, 3) | 100 | Direction.HORIZONTAL
# Z -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# B -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# C -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 2)(1, 2)(2, 2) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# D -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
# P -> (5, 0)(5, 1)(5, 2) | 100 | Direction.HORIZONTAL
#
# O -> (0, 2)(1, 2)(2, 2) | 100 | Direction.VERTICAL
# P -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# Z -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# Q -> (1, 5)(2, 5)(3, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# R -> (3, 3)(4, 3)(5, 3) | 100 | Direction.VERTICAL
# C -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# D -> (4, 4)(5, 4) | 100 | Direction.VERTICAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# B -> (1, 0)(2, 0) | 100 | Direction.VERTICAL
# C -> (1, 1)(2, 1) | 100 | Direction.VERTICAL
# D -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# E -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# P -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# F -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# Q -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# B -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# C -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# D -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (2, 3)(3, 3)(4, 3) | 100 | Direction.VERTICAL
# Z -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# B -> (3, 4)(4, 4) | 100 | Direction.VERTICAL
# C -> (4, 1)(5, 1) | 100 | Direction.VERTICAL
# Q -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# E -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# F -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# O -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 1)(0, 2) | 100 | Direction.HORIZONTAL
# B -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# C -> (1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# O -> (2, 3)(3, 3)(4, 3) | 100 | Direction.VERTICAL
# D -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(0, 1)(0, 2) | 100 | Direction.HORIZONTAL
# P -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# Z -> (1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# B -> (4, 0)(4, 1) | 100 | Direction.HORIZONTAL
# C -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# D -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 1)(0, 2) | 100 | Direction.HORIZONTAL
# C -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# D -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# E -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# O -> (2, 4)(3, 4)(4, 4) | 100 | Direction.VERTICAL
# P -> (3, 1)(3, 2)(3, 3) | 100 | Direction.HORIZONTAL
# F -> (3, 5)(4, 5) | 100 | Direction.VERTICAL
# G -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
# H -> (5, 0)(5, 1) | 100 | Direction.HORIZONTAL
# I -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 1)(0, 2) | 100 | Direction.HORIZONTAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# C -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# P -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# Q -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 1)(0, 2) | 100 | Direction.HORIZONTAL
# O -> (0, 5)(1, 5)(2, 5) | 100 | Direction.VERTICAL
# B -> (1, 0)(1, 1) | 100 | Direction.HORIZONTAL
# P -> (1, 2)(1, 3)(1, 4) | 100 | Direction.HORIZONTAL
# Q -> (2, 0)(3, 0)(4, 0) | 100 | Direction.VERTICAL
# C -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# D -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# F -> (5, 0)(5, 1) | 100 | Direction.HORIZONTAL
# G -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# B -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# D -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# E -> (5, 2)(5, 3) | 100 | Direction.HORIZONTAL
#
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# Z -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# B -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (2, 2)(3, 2)(4, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 100 | Direction.HORIZONTAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# Q -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 1)(0, 2) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# D -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# O -> (1, 5)(2, 5)(3, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# P -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# Q -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# E -> (3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# F -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# G -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# H -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 2)(1, 2)(2, 2) | 100 | Direction.VERTICAL
# P -> (1, 3)(1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# Q -> (2, 3)(3, 3)(4, 3) | 100 | Direction.VERTICAL
# Z -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# B -> (4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# C -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# O -> (0, 2)(0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# B -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# C -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# P -> (2, 5)(3, 5)(4, 5) | 100 | Direction.VERTICAL
# Q -> (3, 1)(3, 2)(3, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 1)(5, 1) | 100 | Direction.VERTICAL
# F -> (5, 2)(5, 3) | 100 | Direction.HORIZONTAL
# G -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# O -> (1, 1)(1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# Z -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# C -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# P -> (3, 1)(4, 1)(5, 1) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 100 | Direction.VERTICAL
# B -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# E -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# F -> (3, 0)(3, 1) | 100 | Direction.HORIZONTAL
# O -> (4, 0)(4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# G -> (4, 4)(5, 4) | 100 | Direction.VERTICAL
# H -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# O -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# Z -> (1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# C -> (3, 2)(4, 2) | 100 | Direction.VERTICAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# D -> (5, 2)(5, 3) | 100 | Direction.HORIZONTAL
#
# O -> (0, 2)(1, 2)(2, 2) | 100 | Direction.VERTICAL
# Z -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# B -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# C -> (2, 3)(3, 3) | 100 | Direction.VERTICAL
# D -> (4, 3)(4, 4) | 100 | Direction.HORIZONTAL
# E -> (5, 1)(5, 2) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 100 | Direction.VERTICAL
# P -> (0, 5)(1, 5)(2, 5) | 100 | Direction.VERTICAL
# Q -> (1, 1)(1, 2)(1, 3) | 100 | Direction.HORIZONTAL
# B -> (2, 1)(3, 1) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# C -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# D -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# R -> (5, 3)(5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 100 | Direction.HORIZONTAL
# O -> (0, 2)(0, 3)(0, 4) | 100 | Direction.HORIZONTAL
# B -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# C -> (3, 2)(4, 2) | 100 | Direction.VERTICAL
# D -> (3, 4)(3, 5) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# P -> (5, 1)(5, 2)(5, 3) | 100 | Direction.HORIZONTAL
#
# O -> (0, 2)(1, 2)(2, 2) | 100 | Direction.VERTICAL
# P -> (0, 3)(1, 3)(2, 3) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# Z -> (3, 2)(3, 3) | 100 | Direction.HORIZONTAL
# B -> (4, 1)(5, 1) | 100 | Direction.VERTICAL
# C -> (4, 4)(5, 4) | 100 | Direction.VERTICAL
# D -> (5, 2)(5, 3) | 100 | Direction.HORIZONTAL
#
# O -> (0, 1)(0, 2)(0, 3) | 3 | Direction.HORIZONTAL
# Z -> (0, 4)(0, 5) | 3 | Direction.HORIZONTAL
# B -> (1, 3)(2, 3) | 3 | Direction.VERTICAL
# C -> (1, 4)(2, 4) | 3 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 3 | Direction.HORIZONTAL
# P -> (3, 3)(3, 4)(3, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(0, 3) | 21 | Direction.HORIZONTAL
# O -> (0, 4)(1, 4)(2, 4) | 9 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 5 | Direction.HORIZONTAL
# B -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# C -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# D -> (4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 2)(1, 2) | 100 | Direction.VERTICAL
# O -> (0, 5)(1, 5)(2, 5) | 12 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# B -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# C -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (3, 3)(3, 4)(3, 5) | 100 | Direction.HORIZONTAL
# D -> (4, 0)(5, 0) | 100 | Direction.VERTICAL
# E -> (4, 3)(5, 3) | 8 | Direction.VERTICAL
# F -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# G -> (5, 1)(5, 2) | 14 | Direction.HORIZONTAL
#
# Z -> (0, 0)(1, 0) | 19 | Direction.VERTICAL
# B -> (0, 3)(1, 3) | 100 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 5 | Direction.HORIZONTAL
# O -> (1, 1)(2, 1)(3, 1) | 100 | Direction.VERTICAL
# D -> (1, 2)(2, 2) | 100 | Direction.VERTICAL
# A -> (2, 3)(2, 4) | 5 | Direction.HORIZONTAL
# E -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# P -> (3, 2)(3, 3)(3, 4) | 100 | Direction.HORIZONTAL
# Q -> (4, 0)(4, 1)(4, 2) | 100 | Direction.HORIZONTAL
# F -> (4, 4)(5, 4) | 100 | Direction.VERTICAL
# G -> (4, 5)(5, 5) | 100 | Direction.VERTICAL
#
# Z -> (0, 1)(0, 2) | 2 | Direction.HORIZONTAL
# O -> (0, 3)(0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# B -> (1, 4)(2, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# C -> (3, 2)(3, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 4)(3, 5) | 100 | Direction.HORIZONTAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 0)(0, 1) | 20 | Direction.HORIZONTAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# D -> (0, 5)(1, 5) | 100 | Direction.VERTICAL
# O -> (1, 0)(1, 1)(1, 2) | 100 | Direction.HORIZONTAL
# E -> (1, 3)(2, 3) | 100 | Direction.VERTICAL
# A -> (2, 1)(2, 2) | 100 | Direction.HORIZONTAL
# F -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# G -> (3, 2)(4, 2) | 2 | Direction.VERTICAL
# P -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# H -> (5, 4)(5, 5) | 100 | Direction.HORIZONTAL
#
# Z -> (0, 1)(0, 2) | 100 | Direction.HORIZONTAL
# B -> (0, 3)(1, 3) | 17 | Direction.VERTICAL
# C -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 2)(2, 3) | 6 | Direction.HORIZONTAL
# D -> (2, 4)(3, 4) | 100 | Direction.VERTICAL
# O -> (4, 1)(4, 2)(4, 3) | 100 | Direction.HORIZONTAL
# E -> (4, 4)(5, 4) | 100 | Direction.VERTICAL
#
# Z -> (0, 1)(1, 1) | 100 | Direction.VERTICAL
# B -> (0, 2)(0, 3) | 100 | Direction.HORIZONTAL
# C -> (0, 4)(1, 4) | 100 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 7 | Direction.HORIZONTAL
# D -> (2, 2)(3, 2) | 100 | Direction.VERTICAL
# O -> (2, 4)(3, 4)(4, 4) | 3 | Direction.VERTICAL
# E -> (4, 2)(5, 2) | 100 | Direction.VERTICAL
#
# O -> (0, 4)(1, 4)(2, 4) | 5 | Direction.VERTICAL
# Z -> (1, 0)(2, 0) | 6 | Direction.VERTICAL
# B -> (1, 1)(2, 1) | 100 | Direction.VERTICAL
# C -> (1, 5)(2, 5) | 100 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 100 | Direction.HORIZONTAL
# D -> (3, 1)(4, 1) | 100 | Direction.VERTICAL
# P -> (3, 2)(4, 2)(5, 2) | 100 | Direction.VERTICAL
# E -> (3, 3)(4, 3) | 100 | Direction.VERTICAL
# F -> (3, 4)(3, 5) | 100 | Direction.HORIZONTAL
#
# O -> (0, 0)(0, 1)(0, 2) | 10 | Direction.HORIZONTAL
# P -> (0, 4)(1, 4)(2, 4) | 10 | Direction.VERTICAL
# Q -> (0, 5)(1, 5)(2, 5) | 10 | Direction.VERTICAL
# A -> (2, 2)(2, 3) | 10 | Direction.HORIZONTAL
# Z -> (4, 2)(5, 2) | 4 | Direction.VERTICAL
# R -> (4, 3)(4, 4)(4, 5) | 100 | Direction.HORIZONTAL
# B -> (5, 3)(5, 4) | 1 | Direction.HORIZONTAL
#
# Z -> (0, 1)(0, 2) | 2 | Direction.HORIZONTAL
# B -> (1, 2)(2, 2) | 2 | Direction.VERTICAL
# C -> (1, 3)(2, 3) | 2 | Direction.VERTICAL
# A -> (2, 0)(2, 1) | 100 | Direction.HORIZONTAL
# D -> (3, 1)(3, 2) | 2 | Direction.HORIZONTAL
#
# O -> (0, 2)(1, 2)(2, 2) | 100 | Direction.VERTICAL
# Z -> (0, 4)(0, 5) | 100 | Direction.HORIZONTAL
# B -> (1, 4)(1, 5) | 100 | Direction.HORIZONTAL
# A -> (2, 0)(2, 1) | 3 | Direction.HORIZONTAL
# C -> (2, 5)(3, 5) | 100 | Direction.VERTICAL
# D -> (4, 3)(5, 3) | 100 | Direction.VERTICAL
# E -> (4, 4)(4, 5) | 100 | Direction.HORIZONTAL

# %% [markdown]
# # Building State Space Search - Uniform Cost Search (UCS)

# %%
class Node(object):
    def __init__(self, board, cost):
        self.board = board
        self.cost = cost
        self.path = []
        self.parent = 0
        self.search = ""
    def __lt__(self, other):
        return self.cost < other.cost
    def __eq__(self, other):
        return self.board == other.board
  
    
class UCS(object):
    def __init__(self):
        self.opened = []
        self.closed = []
        self.count = 0

    def recursivePrinting(self, node):
        if node.cost != 0:
            self.recursivePrinting(node.parent)  
        print(node.board)

    def search(self, board):
        self.opened = []
        self.closed = []
        
        self.count += 1
        #Initialise first Node with cost 0 (different for other algorithms)
        a = Node(copy.deepcopy(board), 0)
        self.opened.append(a)
        a.search = "0 0 0 " + a.board.stringLine()

        start_time = time.time()
        statessearched = 0
        
        f = open("Results\\ucs-search-"+ str(self.count) +".txt", "w")

        while(1):              
            #If open list is empty, exit
            if(len(self.opened)==0):
                print("No Solution")
                #Close last file
                f.close()
                #Write everything to file
                f = open("Results\\ucs-sol-"+ str(self.count) +".txt", "w")
                f.write("--------------------------------------------------------------------------------\n")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n!\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                        f.write(", ")
                f.write("\n\n Sorry, could not solve the puzzle as specified.\nError: no solution found\n")
                runtime = time.time() - start_time
                f.write("Runtime: " + str(runtime) + " seconds")
                f.write("--------------------------------------------------------------------------------")
                f.close()
                
                with open("Results\\all_results.txt", "a") as f:
                    f.write(str(self.count) + "\t\t\tUCS\t\tNA\t\tNA\t\t\t\t" + str(statessearched) + "\t\t\t\t" + str("%5.2f" % runtime) + "\n")
                f.close()
                
                return

            #Pop the best candidate node
            curr = self.opened.pop(0)
            
            #print(curr.search)
            f.write(curr.search + "\n")

            #If the popped node is the solution, exit out and print stuff (later to file)
            if(curr.board.winConditionMet()):
                print("Initial board configuration")
                print()
                print(board)
                print("Car Fuel Available: ", end = '')
                for i in range(len(board.cars)):
                    print(""+board.cars[i].letter+":"+str(board.cars[i].fuel)+", ", end ='')
                print()

                print("Runtime: %s seconds" % (time.time() - start_time))
                print("Number of moves: ", curr.cost)
                print("Search path length: %s states" % statessearched)

                print("------")
                #self.recursivePrinting(curr)
                print("Solution path: ")
                for move in curr.path:
                    print(move[0]+ " "+move[1] + " " + str(move[2])+"; ", end='')

                ######

                #Close last file
                f.close()
                #Write everything to file
                f = open("Results\\ucs-sol-"+ str(self.count) +".txt", "w")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                        f.write(", ")
                f.write("\n\n")
                runtime = time.time() - start_time
                f.write("Runtime: " + str(runtime) + " seconds")
                f.write("\nNumber of moves: " + str(curr.cost))
                f.write("\nSearch path length: " + str(statessearched) + " states")

                # Recursive here....
                f.write("\nSolution path: ")
                for move in curr.path:
                    f.write(move[0]+ " "+move[1] + " " + str(move[2])+"; ")

                f.write("\n\n");
                for move in curr.path:
                    f.write(move[0]+ "\t"+move[1] + "\t" + str(move[2]) + "\t" + str(move[3]) + "\t" + str(move[4])+"\n")

                f.write("\n" + str(curr.board) + "\n")
                f.close()
                
                with open("Results\\all_results.txt", "a") as f:
                    f.write(str(self.count) + "\t\t\tUCS\t\tNA\t\t" + str(curr.cost) + "\t\t\t\t" + str(statessearched) + "\t\t\t\t" + str("%5.2f" % runtime) + "\n")
                f.close()

                return

            #If it's not a solution insert into closed list and increment counter
            self.closed.append(curr)
            statessearched+=1
            #print()
            for c in curr.board.cars:
                paths = curr.board.findCarPaths(c)    
                if len(paths) > 0:  
                    #print("Car ", c.letter, " can move:", paths)

                    for i in range(len(paths)):
                        #Create a new node for successor
                        #Increase the cost of this new node (different in other algorithms)
                        newnode = Node(Board(curr.board.cars), curr.cost+1)   
                        newnode.parent = curr
                        newnode.path = copy.deepcopy(newnode.parent.path)

                        #Apply the move and store it
                        move = newnode.board.moveCar(c.letter, paths[i])
                        newnode.path.append(move)   
                        newnode.search = str(newnode.cost) + " " + str(newnode.cost) + " 0 " + move[4]

                        #If the item is already in the open list, skip it
                        #In other algos, need to check that cost is less
                        #For UCS, this will never be the case, since all costs are 1 in this case (breadth first search)
                        if newnode in self.opened or newnode in self.closed:
                            continue

                        #Insert into open list (in sorted order)
                        bisect.insort(self.opened, newnode)

# %% [markdown]
# # Building State Space Search - Greedy Best First Search (GBFS)

# %%
class HNode(object):
    def __init__(self, board, cost, parentCost):
        self.board = board
        self.cost = cost
        self.hCost = 0
        self.path = []
        self.parent = 0
        self.parentCost = parentCost
        self.search = ""
    def __lt__(self, other):
        return self.cost < other.cost
    def __eq__(self, other):
        return self.board == other.board
    
    def addHeuristic(self, heuristic):
        if heuristic == 1:
            self.cost = self.cost + self.board.h1()
        elif heuristic == 2:
            self.cost = self.cost + self.board.h2()
        elif heuristic == 3:
            self.cost = self.cost + self.board.h3(3)
        elif heuristic == 4:
            self.cost = self.cost + self.board.h4()
        return self.cost
    def setCost(self, cost):
        self.cost = cost
        
        
class GBFS(object):
    def __init__(self):
        self.opened = []
        self.closed = []
        self.count = 0
        
    def next(self):
        self.count += 1
    
    def recursivePrinting(self, node):
        if node.cost != 0:
            self.recursivePrinting(node.parent)  
        print(node.board)
        
    def search(self, board, heuristic):
        self.opened = []
        self.closed = []
        
        #Initialise first Node with cost 0
        a = HNode(copy.deepcopy(board), 0, -1)
        self.opened.append(a)
        a.addHeuristic(heuristic)
        a.search = str(a.cost) + " 0 " + str(a.cost) + " " + a.board.stringLine()
        
        start_time = time.time()
        statessearched = 0
        
        f = open("Results\\gbfs-h"+str(heuristic)+"-search-"+ str(self.count) +".txt", "w")
      
        while(1):              
            #If open list is empty, exit
            if(len(self.opened)==0):
                print("No Solution")
                #Close last file
                f.close()
                #Write everything to file
                f = open("Results\\gbfs-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("--------------------------------------------------------------------------------\n")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n!\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                        f.write(", ")
                f.write("\n\n Sorry, could not solve the puzzle as specified.\nError: no solution found\n")
                runtime = time.time() - start_time
                f.write("Runtime: " + str(runtime) + " seconds")
                f.write("--------------------------------------------------------------------------------")
                f.close()
                
                with open("Results\\all_results.txt", "a") as f:
                    f.write(str(self.count) + "\t\t\tGBFS\t\th" + str(heuristic) + "\t\tNA\t\t\t\t" + str(statessearched) + "\t\t\t\t" + str("%5.2f" % runtime) + "\n")
                f.close()
                
                return
        
            #Pop the best candidate node
            curr = self.opened.pop(0)
            curr.setCost(curr.parentCost + 1)
            
            #print(curr.search)
            f.write(curr.search + "\n")
        
            #If the popped node is the solution, exit out and print stuff (later to file)
            if(curr.board.winConditionMet()):
                print("Initial board configuration")
                print()
                print(board)
                print("Car Fuel Available: ", end = '')
                for i in range(len(board.cars)):
                    print(""+board.cars[i].letter+":"+str(board.cars[i].fuel)+", ", end ='')
                print()
                
                print("Runtime: %s seconds" % (time.time() - start_time))
                print("Number of moves: ", curr.cost)
                print("Search path length: %s states" % statessearched)

                print("------")
                #self.recursivePrinting(curr)
                print("Solution path: ")
                for move in curr.path:
                    print(move[0]+ " "+move[1] + " " + str(move[2])+"; ", end='')
                    
                ######
                #Close last file
                f.close()
                #Write everything to file
                f = open("Results\\gbfs-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                        f.write(", ")
                f.write("\n\n")
                runtime = time.time() - start_time
                f.write("Runtime: " + str(runtime) + " seconds")
                f.write("\nNumber of moves: " + str(curr.cost))
                f.write("\nSearch path length: " + str(statessearched) + " states")

                # Recursive here....
                f.write("\nSolution path: ")
                for move in curr.path:
                    f.write(move[0]+ " "+move[1] + " " + str(move[2])+"; ")

                f.write("\n\n");
                for move in curr.path:
                    f.write(move[0]+ "\t"+move[1] + "\t" + str(move[2]) + "\t" + str(move[3]) + "\t" + str(move[4])+"\n")

                f.write("\n" + str(curr.board) + "\n")
                f.close()
                
                with open("Results\\all_results.txt", "a") as f:
                    f.write(str(self.count) + "\t\t\tGBFS\t\th" + str(heuristic) + "\t\t" + str(curr.cost) + "\t\t\t\t" + str(statessearched) + "\t\t\t\t" + str("%5.2f" % runtime) + "\n")
                f.close()
                
                return

            #If it's not a solution insert into closed list and increment counter
            self.closed.append(curr)
            statessearched+=1
        
            #print()
            for c in curr.board.cars:
                paths = curr.board.findCarPaths(c)    
                if len(paths) > 0:  
                    #print("Car ", c.letter, " can move:", paths)
                    
                    for i in range(len(paths)):
                        #Create a new node for successor
                        newnode = HNode(Board(curr.board.cars), 0, curr.cost)   
                        newnode.parent = curr
                        newnode.path = copy.deepcopy(newnode.parent.path)
                
                        #Apply the move and store it
                        move = newnode.board.moveCar(c.letter, paths[i])
                        newnode.path.append(move)
                        gCost = newnode.cost
                        newnode.addHeuristic(heuristic)
                        newnode.search = str(newnode.cost) + " " + str(gCost) + " " + str(newnode.cost - gCost) + " " + move[4] 
                    
                        #If the node is already in the open or closed list, skip it
                        if newnode in self.opened or newnode in self.closed:
                            continue

                        #Insert into open list (in sorted order)
                        bisect.insort(self.opened, newnode)

# %% [markdown]
# # Building State Space Search - Algorithm A or A* (A/A*)

# %%
class AAStar(object):
    def __init__(self):
        self.opened = []
        self.closed = []
        self.count = 0
        
    def next(self):
        self.count += 1
    
    def recursivePrinting(self, node):
        if node.cost != 0:
            self.recursivePrinting(node.parent)  
        print(node.board)
        
    def search(self, board, heuristic):
        self.opened = []
        self.closed = []
        
        #Initialise first Node with cost 0
        a = HNode(copy.deepcopy(board), 0, -1)
        self.opened.append(a)
        a.addHeuristic(heuristic)
        a.search = str(a.cost) + " 0 " + str(a.cost) + " " + a.board.stringLine()
        
        start_time = time.time()
        statessearched = 0
        
        f = open("Results\\a-h"+str(heuristic)+"-search-"+ str(self.count) +".txt", "w")
      
        while(1):              
            #If open list is empty, exit
            if(len(self.opened)==0):
                print("No Solution")
                #Close last file
                f.close()
                #Write everything to file
                f = open("Results\\a-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("--------------------------------------------------------------------------------\n")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n!\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                        f.write(", ")
                f.write("\n\n Sorry, could not solve the puzzle as specified.\nError: no solution found\n")
                runtime = time.time() - start_time
                f.write("Runtime: " + str(runtime) + " seconds")
                f.write("--------------------------------------------------------------------------------")
                f.close()
                
                with open("Results\\all_results.txt", "a") as f:
                    f.write(str(self.count) + "\t\t\tA/A*\t\th" + str(heuristic) + "\t\tNA\t\t\t\t" + str(statessearched) + "\t\t\t\t" + str("%5.2f" % runtime) + "\n")
                f.close()
                
                return
        
            #Pop the best candidate node
            curr = self.opened.pop(0)
            curr.setCost(curr.parentCost + 1)
            
            #print(curr.search)
            f.write(curr.search + "\n")
        
            #If the popped node is the solution, exit out and print stuff (later to file)
            if(curr.board.winConditionMet()):
                print("Initial board configuration")
                print()
                print(board)
                print("Car Fuel Available: ", end = '')
                for i in range(len(board.cars)):
                    print(""+board.cars[i].letter+":"+str(board.cars[i].fuel)+", ", end ='')
                print()
            
                print("Runtime: %s seconds" % (time.time() - start_time))
                print("Number of moves: ", curr.cost)
                print("Search path length: %s states" % statessearched)

                print("------")
                print("Solution path: ")
                for move in curr.path:
                    print(move[0]+ " "+move[1] + " " + str(move[2])+"; ", end='')
                    
                ######
                
                #Close last file
                f.close()
                #Write everything to file
                f = open("Results\\a-h"+str(heuristic)+"-sol-"+ str(self.count) +".txt", "w")
                f.write("Initial board configuration: " + board.stringLine())
                f.write("\n\n" + str(board) + "\n")
                f.write("Car Fuel Available: ")
                for i in range(len(board.cars)):
                    f.write(""+board.cars[i].letter+":"+str(board.cars[i].fuel))
                    if i < len(board.cars) - 1:
                        f.write(", ")
                f.write("\n\n")
                runtime = time.time() - start_time
                f.write("Runtime: " + str(runtime) + " seconds")
                f.write("\nNumber of moves: " + str(curr.cost))
                f.write("\nSearch path length: " + str(statessearched) + " states")

                # Recursive here....
                f.write("\nSolution path: ")
                for move in curr.path:
                    f.write(move[0]+ " "+move[1] + " " + str(move[2])+"; ")

                f.write("\n\n");
                for move in curr.path:
                    f.write(move[0]+ "\t"+move[1] + "\t" + str(move[2]) + "\t" + str(move[3]) + "\t" + str(move[4])+"\n")
                f.write("\n" + str(curr.board) + "\n")
                f.close()
                
                with open("Results\\all_results.txt", "a") as f:
                    f.write(str(self.count) + "\t\t\tA\A*\t\th" + str(heuristic) + "\t\t" + str(curr.cost) + "\t\t\t\t" + str(statessearched) + "\t\t\t\t" + str("%5.2f" % runtime) + "\n")
                f.close()
                
                return

            #If it's not a solution insert into closed list and increment counter
            self.closed.append(curr)
            statessearched+=1
        
            #print()
            for c in curr.board.cars:
                paths = curr.board.findCarPaths(c)    
                if len(paths) > 0:  
                    #print("Car ", c.letter, " can move:", paths)
                    
                    for i in range(len(paths)):
                        #Create a new node for successor
                        newnode = HNode(Board(curr.board.cars), curr.cost+1, curr.cost)   
                        newnode.parent = curr
                        newnode.path = copy.deepcopy(newnode.parent.path)
                
                        #Apply the move and store it
                        move = newnode.board.moveCar(c.letter, paths[i])
                        newnode.path.append(move)
                        gCost = newnode.cost
                        newnode.addHeuristic(heuristic)
                        newnode.search = str(newnode.cost) + " " + str(gCost) + " " + str(newnode.cost - gCost) + " " + move[4]      
                    
                        #If the node is already in the open or closed list, skip if the cost in is higher, else replace
                        if newnode in self.opened:
                            for n in self.opened:
                                if n == newnode and n.cost > newnode.cost:
                                    self.opened.remove(n)
                                    bisect.insort(self.opened, newnode)
                                    break
                            continue
                        elif newnode in self.closed:
                            for n in self.closed:
                                if n == newnode and n.cost > newnode.cost:
                                    self.closed.remove(n)
                                    bisect.insort(self.opened, newnode)
                                    break
                            continue
                        else:
                            #Insert into open list (in sorted order)
                            bisect.insort(self.opened, newnode)

# %% [markdown]
# # Running the 50 simulations

# %%
f = open("Results\\all_results.txt", "w")
f.write("Puzzle number\tAlgorithm\tHeuristic\tLength of solution\tLength of search path\tExecution Time (seconds)\n")
f.close()

# %%
ucs = UCS()
gbfs = GBFS()
aastar = AAStar()

for b in boards:
    currentBoard = Board(b.cars) 
    ucs.search(currentBoard)
    gbfs.next()
    for i in range(1,5): 
        gbfs.search(currentBoard, i)
    aastar.next()
    for i in range(1,5): 
        aastar.search(currentBoard, i)
    f = open("Results\\all_results.txt", "a")
    f.write("\n")
    f.close()
# Out:
# Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 7.94587516784668 seconds
# Number of moves:  9
# Search path length: 1505 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.8062870502471924 seconds
# Number of moves:  9
# Search path length: 229 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.7832028865814209 seconds
# Number of moves:  9
# Search path length: 229 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.8423283100128174 seconds
# Number of moves:  9
# Search path length: 229 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.7617623805999756 seconds
# Number of moves:  9
# Search path length: 220 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 7.797882318496704 seconds
# Number of moves:  9
# Search path length: 1199 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 7.643742561340332 seconds
# Number of moves:  9
# Search path length: 1199 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 0.9241964817047119 seconds
# Number of moves:  9
# Search path length: 257 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# Z.BOOO
# Z.B...
# .AAC..
# .D.C..
# .DPPPE
# .....E
#
# Car Fuel Available: Z:100, B:100, O:100, A:100, C:100, D:100, P:100, E:100,
# Runtime: 4.6515350341796875 seconds
# Number of moves:  9
# Search path length: 823 states
# ------
# Solution path:
# Z down 3; A left 1; B down 1; O left 3; C up 2; E up 4; P right 1; B down 2; A right 4; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 2.9277260303497314 seconds
# Number of moves:  5
# Search path length: 665 states
# ------
# Solution path:
# Z left 1; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 0.05884099006652832 seconds
# Number of moves:  5
# Search path length: 18 states
# ------
# Solution path:
# Z left 1; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 0.05873465538024902 seconds
# Number of moves:  5
# Search path length: 18 states
# ------
# Solution path:
# Z left 1; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 0.05886054039001465 seconds
# Number of moves:  5
# Search path length: 18 states
# ------
# Solution path:
# Z left 1; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 0.06258296966552734 seconds
# Number of moves:  5
# Search path length: 18 states
# ------
# Solution path:
# Z left 2; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 2.133967399597168 seconds
# Number of moves:  5
# Search path length: 406 states
# ------
# Solution path:
# Z left 1; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 2.0990724563598633 seconds
# Number of moves:  5
# Search path length: 406 states
# ------
# Solution path:
# Z left 1; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 0.06100964546203613 seconds
# Number of moves:  5
# Search path length: 18 states
# ------
# Solution path:
# Z left 1; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....ZZ
# ....O.
# .AA.OB
# ....OB
# .....C
# ...DDC
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100,
# Runtime: 1.7422518730163574 seconds
# Number of moves:  5
# Search path length: 333 states
# ------
# Solution path:
# Z left 2; B up 2; D left 1; O down 2; A right 3; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.02891373634338379 seconds
# Number of moves:  7
# Search path length: 26 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.019715070724487305 seconds
# Number of moves:  7
# Search path length: 17 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.020292043685913086 seconds
# Number of moves:  7
# Search path length: 17 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.018717527389526367 seconds
# Number of moves:  7
# Search path length: 17 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.016206741333007812 seconds
# Number of moves:  7
# Search path length: 13 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.028434038162231445 seconds
# Number of moves:  7
# Search path length: 25 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.028393030166625977 seconds
# Number of moves:  7
# Search path length: 25 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.021828651428222656 seconds
# Number of moves:  7
# Search path length: 20 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ....Z.
# ....Z.
# AA.BC.
# .O.BC.
# .ODDEE
# .O....
#
# Car Fuel Available: Z:100, A:100, B:100, C:100, O:100, D:100, E:100,
# Runtime: 0.030417919158935547 seconds
# Number of moves:  7
# Search path length: 25 states
# ------
# Solution path:
# B up 2; A right 2; O up 2; D left 2; E left 2; C down 1; A right 2; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 1.3481354713439941 seconds
# Number of moves:  6
# Search path length: 440 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.08320999145507812 seconds
# Number of moves:  6
# Search path length: 33 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.08198332786560059 seconds
# Number of moves:  6
# Search path length: 33 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.08342838287353516 seconds
# Number of moves:  6
# Search path length: 33 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.04748964309692383 seconds
# Number of moves:  6
# Search path length: 19 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.8288586139678955 seconds
# Number of moves:  6
# Search path length: 244 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.8576552867889404 seconds
# Number of moves:  6
# Search path length: 244 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.09088397026062012 seconds
# Number of moves:  6
# Search path length: 37 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ..ZOOO
# ..ZP.B
# .AAP.B
# ...P..
# .....C
# .....C
#
# Car Fuel Available: Z:100, O:100, P:100, B:100, A:100, C:100,
# Runtime: 0.7154815196990967 seconds
# Number of moves:  6
# Search path length: 204 states
# ------
# Solution path:
# P down 2; A left 1; Z down 3; O left 1; B up 1; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 221.00480341911316 seconds
# Number of moves:  8
# Search path length: 7144 states
# ------
# Solution path:
# B left 2; C up 1; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 9.791677713394165 seconds
# Number of moves:  8
# Search path length: 1198 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 9.985641956329346 seconds
# Number of moves:  8
# Search path length: 1198 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 9.812827110290527 seconds
# Number of moves:  8
# Search path length: 1198 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 8.869987726211548 seconds
# Number of moves:  8
# Search path length: 1099 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 104.44043374061584 seconds
# Number of moves:  8
# Search path length: 4383 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 107.98424792289734 seconds
# Number of moves:  8
# Search path length: 4383 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 17.848777055740356 seconds
# Number of moves:  8
# Search path length: 1486 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ZZ..O.
# ..BBOC
# ..AAOC
# ...DD.
# ..EFF.
# ..E...
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 94.71383094787598 seconds
# Number of moves:  8
# Search path length: 4037 states
# ------
# Solution path:
# C up 1; B left 2; A left 2; D left 3; E up 4; F left 1; O down 3; A right 4; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 5.7534050941467285 seconds
# Number of moves:  6
# Search path length: 1170 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.31996703147888184 seconds
# Number of moves:  6
# Search path length: 99 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.31664252281188965 seconds
# Number of moves:  6
# Search path length: 99 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.31853222846984863 seconds
# Number of moves:  6
# Search path length: 99 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.31986021995544434 seconds
# Number of moves:  6
# Search path length: 99 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 3.2896828651428223 seconds
# Number of moves:  6
# Search path length: 609 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 3.2975223064422607 seconds
# Number of moves:  6
# Search path length: 609 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 0.375446081161499 seconds
# Number of moves:  6
# Search path length: 108 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# ...O..
# ...O.Z
# .AAO.Z
# ......
# B.C...
# B.CPPP
#
# Car Fuel Available: O:100, Z:100, A:100, B:100, C:100, P:100,
# Runtime: 3.27671217918396 seconds
# Number of moves:  6
# Search path length: 609 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; P left 3; O down 3; A right 3; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.17315435409545898 seconds
# Number of moves:  6
# Search path length: 83 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.029059886932373047 seconds
# Number of moves:  6
# Search path length: 17 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.0294036865234375 seconds
# Number of moves:  6
# Search path length: 17 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.02846240997314453 seconds
# Number of moves:  6
# Search path length: 17 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.024823427200317383 seconds
# Number of moves:  6
# Search path length: 14 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.09836173057556152 seconds
# Number of moves:  6
# Search path length: 57 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.09933924674987793 seconds
# Number of moves:  6
# Search path length: 57 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.03144097328186035 seconds
# Number of moves:  6
# Search path length: 19 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# .....Z
# ..OOOZ
# AA.B.C
# ...B.C
# .DDPPP
# ......
#
# Car Fuel Available: Z:100, O:100, A:100, B:100, C:100, D:100, P:100,
# Runtime: 0.08733010292053223 seconds
# Number of moves:  6
# Search path length: 50 states
# ------
# Solution path:
# O left 2; B up 2; D left 1; P left 1; C down 1; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 1.9184658527374268 seconds
# Number of moves:  6
# Search path length: 527 states
# ------
# Solution path:
# O right 2; B up 1; D down 2; P left 2; C down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.06132078170776367 seconds
# Number of moves:  6
# Search path length: 24 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.061922311782836914 seconds
# Number of moves:  6
# Search path length: 24 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.06148409843444824 seconds
# Number of moves:  6
# Search path length: 24 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.041996002197265625 seconds
# Number of moves:  6
# Search path length: 16 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 1.3005845546722412 seconds
# Number of moves:  6
# Search path length: 341 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 1.2680752277374268 seconds
# Number of moves:  6
# Search path length: 341 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.061504364013671875 seconds
# Number of moves:  6
# Search path length: 24 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZOOO..
# Z.BC.D
# AABC.D
# ..PPP.
# ......
# ......
#
# Car Fuel Available: Z:100, O:100, B:100, C:100, D:100, A:100, P:100,
# Runtime: 0.8767049312591553 seconds
# Number of moves:  6
# Search path length: 233 states
# ------
# Solution path:
# D up 1; P left 2; C down 3; P right 3; B down 2; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 2.0186939239501953 seconds
# Number of moves:  9
# Search path length: 516 states
# ------
# Solution path:
# A left 2; O up 2; F up 2; G left 4; D down 2; E down 2; O down 2; F down 1; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.32492780685424805 seconds
# Number of moves:  13
# Search path length: 121 states
# ------
# Solution path:
# A left 1; F up 2; G left 1; E down 2; A left 1; O up 2; G left 1; D down 2; G left 1; F down 1; G left 1; O down 2; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.35373854637145996 seconds
# Number of moves:  13
# Search path length: 121 states
# ------
# Solution path:
# A left 1; F up 2; G left 1; E down 2; A left 1; O up 2; G left 1; D down 2; G left 1; F down 1; G left 1; O down 2; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.32742834091186523 seconds
# Number of moves:  13
# Search path length: 121 states
# ------
# Solution path:
# A left 1; F up 2; G left 1; E down 2; A left 1; O up 2; G left 1; D down 2; G left 1; F down 1; G left 1; O down 2; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.2709970474243164 seconds
# Number of moves:  11
# Search path length: 100 states
# ------
# Solution path:
# A left 1; F up 2; G left 1; E down 2; A left 1; O up 2; G left 3; D down 2; O down 2; F down 1; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 1.949087381362915 seconds
# Number of moves:  9
# Search path length: 423 states
# ------
# Solution path:
# A left 2; O up 2; F up 2; G left 4; D down 2; E down 2; O down 2; F down 1; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 1.9216692447662354 seconds
# Number of moves:  9
# Search path length: 423 states
# ------
# Solution path:
# A left 2; O up 2; F up 2; G left 4; D down 2; E down 2; O down 2; F down 1; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 0.3429121971130371 seconds
# Number of moves:  12
# Search path length: 121 states
# ------
# Solution path:
# A left 2; F up 3; G left 1; E down 2; O up 2; G left 1; D down 2; G left 1; F down 2; G left 1; O down 2; A right 4; Initial board configuration
#
# ZZBBCC
# ....DE
# ..AADE
# ..O...
# ..OFGG
# ..OF..
#
# Car Fuel Available: Z:100, B:100, C:100, D:100, E:100, A:100, O:100, F:100, G:100,
# Runtime: 1.483564853668213 seconds
# Number of moves:  9
# Search path length: 317 states
# ------
# Solution path:
# A left 2; O up 2; F up 2; G left 4; D down 2; E down 2; O down 2; F down 1; A right 4; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 26.392348051071167 seconds
# Number of moves:  19
# Search path length: 3570 states
# ------
# Solution path:
# J right 2; E down 1; A left 3; E up 1; J left 2; K left 3; H down 1; G right 1; B down 4; C left 1; G left 1; D down 1; O right 3; E up 2; A right 3; E down 2; O left 1; D up 2; A right 1; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 13.472391128540039 seconds
# Number of moves:  23
# Search path length: 2166 states
# ------
# Solution path:
# J right 2; E down 1; A left 2; B down 1; C left 1; D up 1; Z right 1; E down 1; F right 1; K left 1; H down 1; G right 1; B down 1; O right 1; I up 4; A left 1; F left 1; E up 2; J left 2; B down 1; J left 1; E down 1; A right 4; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 13.60699462890625 seconds
# Number of moves:  23
# Search path length: 2166 states
# ------
# Solution path:
# J right 2; E down 1; A left 2; B down 1; C left 1; D up 1; Z right 1; E down 1; F right 1; K left 1; H down 1; G right 1; B down 1; O right 1; I up 4; A left 1; F left 1; E up 2; J left 2; B down 1; J left 1; E down 1; A right 4; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 13.443283319473267 seconds
# Number of moves:  23
# Search path length: 2166 states
# ------
# Solution path:
# J right 2; E down 1; A left 2; B down 1; C left 1; D up 1; Z right 1; E down 1; F right 1; K left 1; H down 1; G right 1; B down 1; O right 1; I up 4; A left 1; F left 1; E up 2; J left 2; B down 1; J left 1; E down 1; A right 4; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 10.378969192504883 seconds
# Number of moves:  24
# Search path length: 1763 states
# ------
# Solution path:
# J right 2; E down 1; A left 2; B down 1; C left 1; D up 1; A left 1; K left 1; H down 1; G right 1; E up 1; J left 2; B down 2; K left 2; B down 1; G left 1; D down 2; O right 3; E up 2; A right 3; E down 2; O left 1; D up 2; A right 1; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 28.386384963989258 seconds
# Number of moves:  19
# Search path length: 3094 states
# ------
# Solution path:
# J right 2; E down 1; A left 3; K left 3; H down 1; G right 1; E up 1; J left 2; B down 4; G left 1; D down 1; O right 3; E up 2; C left 1; A right 3; E down 2; O left 1; D up 2; A right 1; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 28.471274614334106 seconds
# Number of moves:  19
# Search path length: 3094 states
# ------
# Solution path:
# J right 2; E down 1; A left 3; K left 3; H down 1; G right 1; E up 1; J left 2; B down 4; G left 1; D down 1; O right 3; E up 2; C left 1; A right 3; E down 2; O left 1; D up 2; A right 1; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 23.926727533340454 seconds
# Number of moves:  19
# Search path length: 2644 states
# ------
# Solution path:
# J right 2; E down 1; A left 3; K left 3; H down 1; G right 1; E up 1; J left 2; B down 4; G left 1; D down 1; O right 3; E up 2; C left 1; A right 3; E down 2; O left 1; D up 2; A right 1; Initial board configuration
#
# ZZ.BCC
# OOOB.D
# ..EAAD
# FFEGGH
# IJJ..H
# I...KK
#
# Car Fuel Available: Z:100, B:100, C:100, O:100, D:100, E:100, A:100, F:100, G:100, H:100, I:100, J:100, K:100,
# Runtime: 24.935737133026123 seconds
# Number of moves:  19
# Search path length: 2817 states
# ------
# Solution path:
# J right 2; E down 1; A left 3; K left 3; H down 1; G right 1; E up 1; J left 2; B down 4; G left 1; D down 1; O right 3; E up 2; C left 1; A right 3; E down 2; O left 1; D up 2; A right 1; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 1.4093902111053467 seconds
# Number of moves:  7
# Search path length: 465 states
# ------
# Solution path:
# Z left 2; B up 1; E up 1; F left 3; D down 1; E down 1; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.1372220516204834 seconds
# Number of moves:  8
# Search path length: 71 states
# ------
# Solution path:
# Z left 2; B up 1; E up 1; F left 1; D down 1; F left 2; E down 1; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.13843441009521484 seconds
# Number of moves:  8
# Search path length: 71 states
# ------
# Solution path:
# Z left 2; B up 1; E up 1; F left 1; D down 1; F left 2; E down 1; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.13680076599121094 seconds
# Number of moves:  8
# Search path length: 71 states
# ------
# Solution path:
# Z left 2; B up 1; E up 1; F left 1; D down 1; F left 2; E down 1; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.07811641693115234 seconds
# Number of moves:  7
# Search path length: 44 states
# ------
# Solution path:
# Z left 2; B up 1; E up 1; F left 3; D down 1; E down 1; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 1.263413906097412 seconds
# Number of moves:  7
# Search path length: 371 states
# ------
# Solution path:
# E down 1; B down 1; C left 3; D up 2; Z left 2; B up 2; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 1.2593488693237305 seconds
# Number of moves:  7
# Search path length: 371 states
# ------
# Solution path:
# E down 1; B down 1; C left 3; D up 2; Z left 2; B up 2; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.16185283660888672 seconds
# Number of moves:  8
# Search path length: 76 states
# ------
# Solution path:
# E down 1; B down 1; C left 1; D up 2; Z left 2; C left 2; B up 2; A right 4; Initial board configuration
#
# ...ZZ.
# ...BCC
# AA.B.D
# ...E.D
# ...EFF
# ......
#
# Car Fuel Available: Z:100, B:100, C:100, A:100, D:100, E:100, F:100,
# Runtime: 0.9831709861755371 seconds
# Number of moves:  7
# Search path length: 277 states
# ------
# Solution path:
# Z left 2; B up 1; E up 1; F left 3; D down 1; E down 1; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 337.6193356513977 seconds
# Number of moves:  31
# Search path length: 11130 states
# ------
# Solution path:
# D down 1; E left 2; F up 1; P up 2; I right 1; J left 1; H down 1; K right 1; D down 2; A right 1; G right 3; Z down 3; H up 1; J right 1; O down 3; B left 2; C left 1; E left 2; A left 2; H up 3; P up 1; G right 1; D up 3; G left 2; I left 2; F down 2; K left 1; P down 3; C right 1; D up 1; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 47.698750734329224 seconds
# Number of moves:  41
# Search path length: 4254 states
# ------
# Solution path:
# D down 1; E left 1; P up 2; I right 1; D down 1; E left 1; A right 1; Z down 1; J left 1; H down 1; G right 1; O down 1; B left 2; C left 2; F up 2; P up 1; K right 1; D down 1; G right 3; Z down 2; D up 1; E left 1; A left 1; K left 1; D up 2; G left 1; I left 1; P down 3; F down 1; C right 2; D up 1; H up 1; J right 1; O down 2; E left 1; A left 1; H up 3; G left 1; I left 1; F down 2; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 49.01888155937195 seconds
# Number of moves:  41
# Search path length: 4254 states
# ------
# Solution path:
# D down 1; E left 1; P up 2; I right 1; D down 1; E left 1; A right 1; Z down 1; J left 1; H down 1; G right 1; O down 1; B left 2; C left 2; F up 2; P up 1; K right 1; D down 1; G right 3; Z down 2; D up 1; E left 1; A left 1; K left 1; D up 2; G left 1; I left 1; P down 3; F down 1; C right 2; D up 1; H up 1; J right 1; O down 2; E left 1; A left 1; H up 3; G left 1; I left 1; F down 2; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 47.68467116355896 seconds
# Number of moves:  41
# Search path length: 4254 states
# ------
# Solution path:
# D down 1; E left 1; P up 2; I right 1; D down 1; E left 1; A right 1; Z down 1; J left 1; H down 1; G right 1; O down 1; B left 2; C left 2; F up 2; P up 1; K right 1; D down 1; G right 3; Z down 2; D up 1; E left 1; A left 1; K left 1; D up 2; G left 1; I left 1; P down 3; F down 1; C right 2; D up 1; H up 1; J right 1; O down 2; E left 1; A left 1; H up 3; G left 1; I left 1; F down 2; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 45.51070547103882 seconds
# Number of moves:  41
# Search path length: 4043 states
# ------
# Solution path:
# D down 1; E left 2; P up 1; K right 1; P up 1; I right 1; D down 1; A right 1; Z down 1; J left 1; H down 1; G right 1; O down 1; B left 2; C left 2; F up 2; D down 1; P up 1; G right 3; Z down 2; D up 1; E left 1; A left 1; K left 1; D up 2; G left 1; I left 1; P down 3; F down 1; C right 2; D up 1; H up 1; J right 1; O down 2; E left 1; A left 1; H up 3; G left 1; I left 1; F down 2; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 375.82717990875244 seconds
# Number of moves:  31
# Search path length: 9519 states
# ------
# Solution path:
# D down 1; E left 2; P up 2; I right 1; K right 1; D down 2; A right 1; F up 1; J left 1; H down 1; G right 3; Z down 3; H up 1; J right 1; O down 3; B left 2; C left 1; E left 2; A left 2; H up 3; P up 1; G right 1; D up 3; G left 2; I left 2; F down 2; K left 1; P down 3; C right 1; D up 1; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 384.5061995983124 seconds
# Number of moves:  31
# Search path length: 9519 states
# ------
# Solution path:
# D down 1; E left 2; P up 2; I right 1; K right 1; D down 2; A right 1; F up 1; J left 1; H down 1; G right 3; Z down 3; H up 1; J right 1; O down 3; B left 2; C left 1; E left 2; A left 2; H up 3; P up 1; G right 1; D up 3; G left 2; I left 2; F down 2; K left 1; P down 3; C right 1; D up 1; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 151.30432653427124 seconds
# Number of moves:  31
# Search path length: 6531 states
# ------
# Solution path:
# D down 1; E left 2; P up 2; I right 1; K right 1; D down 2; A right 1; F up 1; J left 1; H down 1; G right 3; Z down 3; H up 1; J right 1; O down 3; B left 2; C left 1; E left 2; A left 2; H up 3; P up 1; G right 1; D up 3; G left 2; I left 2; F down 2; K left 1; P down 3; C right 1; D up 1; A right 4; Initial board configuration
#
# OZBBCC
# OZ.DEE
# OAADF.
# GGH.FP
# ..HIIP
# .JJKKP
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, A:100, F:100, G:100, H:100, P:100, I:100, J:100, K:100,
# Runtime: 315.0830588340759 seconds
# Number of moves:  31
# Search path length: 8591 states
# ------
# Solution path:
# D down 1; E left 2; P up 2; I right 1; K right 1; D down 2; A right 1; F up 1; J left 1; H down 1; G right 3; Z down 3; H up 1; J right 1; O down 3; B left 2; C left 1; E left 2; A left 2; H up 3; P up 1; G right 1; D up 3; G left 2; I left 2; F down 2; K left 1; P down 3; C right 1; D up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 3.4637436866760254 seconds
# Number of moves:  19
# Search path length: 884 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; P right 1; J right 1; O down 3; A left 2; B down 3; E down 1; C left 3; D up 1; E up 1; F up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 1.9405829906463623 seconds
# Number of moves:  22
# Search path length: 511 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; A left 1; E down 1; C left 1; D up 1; P right 1; J right 1; O down 3; A left 1; B down 3; C left 1; F up 1; C left 1; E up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 1.800084114074707 seconds
# Number of moves:  22
# Search path length: 511 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; A left 1; E down 1; C left 1; D up 1; P right 1; J right 1; O down 3; A left 1; B down 3; C left 1; F up 1; C left 1; E up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 1.7470932006835938 seconds
# Number of moves:  22
# Search path length: 511 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; A left 1; E down 1; C left 1; D up 1; P right 1; J right 1; O down 3; A left 1; B down 3; C left 1; F up 1; C left 1; E up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 1.273451805114746 seconds
# Number of moves:  19
# Search path length: 368 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; P right 1; J right 1; O down 3; A left 2; B down 3; E down 1; C left 3; D up 1; E up 1; F up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 2.554304838180542 seconds
# Number of moves:  19
# Search path length: 629 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; P right 1; J right 1; O down 3; A left 2; B down 3; E down 1; C left 3; D up 1; E up 1; F up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 2.5291690826416016 seconds
# Number of moves:  19
# Search path length: 629 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; P right 1; J right 1; O down 3; A left 2; B down 3; E down 1; C left 3; D up 1; E up 1; F up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 1.9398846626281738 seconds
# Number of moves:  20
# Search path length: 533 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; P right 1; J right 1; O down 3; A left 2; B down 3; E down 1; C left 2; D up 1; F up 1; C left 1; E up 1; A right 4; Initial board configuration
#
# OZBCCD
# OZBEFD
# OAAEF.
# ...GHH
# II.G..
# JJPPP.
#
# Car Fuel Available: O:100, Z:100, B:100, C:100, D:100, E:100, F:100, A:100, G:100, H:100, I:100, J:100, P:100,
# Runtime: 2.256662607192993 seconds
# Number of moves:  19
# Search path length: 569 states
# ------
# Solution path:
# D down 1; C right 1; E up 1; G up 1; I right 4; G down 1; A right 1; Z down 3; P right 1; J right 1; O down 3; A left 2; B down 3; E down 1; C left 3; D up 1; E up 1; F up 1; A right 4; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 2.917924165725708 seconds
# Number of moves:  20
# Search path length: 741 states
# ------
# Solution path:
# C down 1; P down 1; A left 1; B down 2; O left 1; D left 3; F up 2; H up 2; Q right 1; B down 1; A right 1; Z down 1; O left 2; C up 2; E up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.8368782997131348 seconds
# Number of moves:  24
# Search path length: 232 states
# ------
# Solution path:
# C down 1; D left 1; P down 1; A left 1; B down 1; O left 1; F up 2; B down 1; O left 1; D left 1; E up 2; H up 2; Q right 1; B down 1; D left 1; A right 1; Z down 1; O left 1; C up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.8009688854217529 seconds
# Number of moves:  24
# Search path length: 232 states
# ------
# Solution path:
# C down 1; D left 1; P down 1; A left 1; B down 1; O left 1; F up 2; B down 1; O left 1; D left 1; E up 2; H up 2; Q right 1; B down 1; D left 1; A right 1; Z down 1; O left 1; C up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.8358447551727295 seconds
# Number of moves:  24
# Search path length: 232 states
# ------
# Solution path:
# C down 1; D left 1; P down 1; A left 1; B down 1; O left 1; F up 2; B down 1; O left 1; D left 1; E up 2; H up 2; Q right 1; B down 1; D left 1; A right 1; Z down 1; O left 1; C up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 0.7745223045349121 seconds
# Number of moves:  24
# Search path length: 224 states
# ------
# Solution path:
# C down 1; D left 1; P down 1; A left 1; B down 1; O left 1; F up 2; B down 1; O left 1; D left 1; E up 2; H up 2; Q right 1; B down 1; D left 1; A right 1; Z down 1; O left 1; C up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 3.3361856937408447 seconds
# Number of moves:  20
# Search path length: 735 states
# ------
# Solution path:
# C down 1; P down 1; A left 1; B down 2; O left 2; D left 3; E up 2; F up 2; H up 2; Q right 1; B down 1; A right 1; Z down 1; O left 1; C up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 3.2832860946655273 seconds
# Number of moves:  20
# Search path length: 735 states
# ------
# Solution path:
# C down 1; P down 1; A left 1; B down 2; O left 2; D left 3; E up 2; F up 2; H up 2; Q right 1; B down 1; A right 1; Z down 1; O left 1; C up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# Car Fuel Available: Z:100, B:100, O:100, C:100, D:100, P:100, A:100, E:100, F:100, G:100, Q:100, H:100,
# Runtime: 2.7422828674316406 seconds
# Number of moves:  22
# Search path length: 610 states
# ------
# Solution path:
# C down 1; D left 1; P down 1; A left 1; B down 2; O left 2; F up 2; D left 1; E up 2; H up 2; Q right 1; B down 1; D left 1; A right 1; Z down 1; O left 1; C up 2; A right 2; B up 1; Q left 1; H down 1; A right 1; Initial board configuration
#
# Z.BOOO
# Z.BCDD
# PAACEF
# PG..EF
# PGQQQH
# .....H
#
# ...
#
# ..Z..O
# ..Z..O
# AAB..O
# .CBPPP
# DC.EFF
# DGGE..
#
# Car Fuel Available: Z:100, O:12, A:100, B:100, C:100, P:100, D:100, E:8, F:100, G:14,
# Runtime: 3.2087204456329346 seconds
# Number of moves:  12
# Search path length: 642 states
# ------
# Solution path:
# B down 1; A right 2; C up 3; A left 1; D up 3; G left 1; B down 1; P left 3; E up 4; F left 1; O down 3; A right 3; Initial board configuration
#
# ..Z..O
# ..Z..O
# AAB..O
# .CBPPP
# DC.EFF
# DGGE..
#
# Car Fuel Available: Z:100, O:12, A:100, B:100, C:100, P:100, D:100, E:8, F:100, G:14,
# Runtime: 2.4798471927642822 seconds
# Number of moves:  12
# Search path length: 521 states
# ------
# Solution path:
# B down 1; A right 2; C up 3; A left 1; D up 3; G left 1; B down 1; P left 3; E up 4; F left 1; O down 3; A right 3; Initial board configuration
#
# ..Z..O
# ..Z..O
# AAB..O
# .CBPPP
# DC.EFF
# DGGE..
#
# Car Fuel Available: Z:100, O:12, A:100, B:100, C:100, P:100, D:100, E:8, F:100, G:14,
# Runtime: 3.273918867111206 seconds
# Number of moves:  12
# Search path length: 642 states
# ------
# Solution path:
# B down 1; A right 2; C up 3; A left 1; D up 3; G left 1; B down 1; P left 3; E up 4; F left 1; O down 3; A right 3; No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.6583821773529053 seconds
# Number of moves:  5
# Search path length: 234 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.2511429786682129 seconds
# Number of moves:  5
# Search path length: 95 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.24883008003234863 seconds
# Number of moves:  5
# Search path length: 95 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.2585735321044922 seconds
# Number of moves:  5
# Search path length: 95 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.1019294261932373 seconds
# Number of moves:  5
# Search path length: 40 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.5020182132720947 seconds
# Number of moves:  5
# Search path length: 168 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.4919867515563965 seconds
# Number of moves:  5
# Search path length: 168 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.26411867141723633 seconds
# Number of moves:  5
# Search path length: 95 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; Initial board configuration
#
# .ZZOOO
# ....B.
# AA..B.
# ..CCDD
# ...PPP
# ......
#
# Car Fuel Available: Z:2, O:100, B:100, A:100, C:100, D:100, P:100,
# Runtime: 0.3121635913848877 seconds
# Number of moves:  5
# Search path length: 106 states
# ------
# Solution path:
# C left 2; D left 2; P left 2; B down 2; A right 4; No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.7466182708740234 seconds
# Number of moves:  7
# Search path length: 302 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.1504654884338379 seconds
# Number of moves:  7
# Search path length: 66 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.1510474681854248 seconds
# Number of moves:  7
# Search path length: 66 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.1486053466796875 seconds
# Number of moves:  7
# Search path length: 66 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.08487892150878906 seconds
# Number of moves:  7
# Search path length: 40 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.6664698123931885 seconds
# Number of moves:  7
# Search path length: 248 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.6810586452484131 seconds
# Number of moves:  7
# Search path length: 248 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.16451525688171387 seconds
# Number of moves:  7
# Search path length: 70 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; Initial board configuration
#
# .ZZBCC
# ...B..
# ..AAD.
# ....D.
# .OOOE.
# ....E.
#
# Car Fuel Available: Z:100, B:17, C:100, A:6, D:100, O:100, E:100,
# Runtime: 0.43756890296936035 seconds
# Number of moves:  7
# Search path length: 166 states
# ------
# Solution path:
# Z left 1; A left 1; O left 1; B down 3; C left 2; D up 2; A right 3; No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 25.829090356826782 seconds
# Number of moves:  11
# Search path length: 3037 states
# ------
# Solution path:
# Z up 1; B up 1; C up 1; A left 2; D down 1; P up 3; E up 3; F left 4; O down 3; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 6.951690196990967 seconds
# Number of moves:  12
# Search path length: 1217 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; E up 3; P up 3; F left 2; O down 3; D down 1; F left 2; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 6.894168376922607 seconds
# Number of moves:  12
# Search path length: 1217 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; E up 3; P up 3; F left 2; O down 3; D down 1; F left 2; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 6.925034284591675 seconds
# Number of moves:  12
# Search path length: 1217 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; E up 3; P up 3; F left 2; O down 3; D down 1; F left 2; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 6.9910664558410645 seconds
# Number of moves:  12
# Search path length: 1217 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; E up 3; P up 3; F left 2; O down 3; D down 1; F left 2; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 22.75604009628296 seconds
# Number of moves:  11
# Search path length: 2274 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; D down 1; E up 3; P up 3; F left 4; O down 3; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 23.005356788635254 seconds
# Number of moves:  11
# Search path length: 2274 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; D down 1; E up 3; P up 3; F left 4; O down 3; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 7.325830936431885 seconds
# Number of moves:  12
# Search path length: 1037 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; E up 3; P up 3; F left 2; O down 3; D down 1; F left 2; P down 3; A right 4; Initial board configuration
#
# ....O.
# ZB..OC
# ZBAAOC
# .DPEFF
# .DPE..
# ..P...
#
# Car Fuel Available: O:5, Z:6, B:100, C:100, A:100, D:100, P:100, E:100, F:100,
# Runtime: 23.013137102127075 seconds
# Number of moves:  11
# Search path length: 2274 states
# ------
# Solution path:
# C up 1; Z up 1; B up 1; A left 2; D down 1; E up 3; P up 3; F left 4; O down 3; P down 3; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 3.5882086753845215 seconds
# Number of moves:  9
# Search path length: 974 states
# ------
# Solution path:
# A left 2; Z up 2; R left 2; Q down 3; B left 1; P down 3; O right 3; Z up 2; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 0.4467289447784424 seconds
# Number of moves:  11
# Search path length: 187 states
# ------
# Solution path:
# P down 1; Q down 1; O right 3; A left 2; Z up 4; R left 1; Q down 2; R left 1; B left 1; P down 2; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 0.44600915908813477 seconds
# Number of moves:  11
# Search path length: 187 states
# ------
# Solution path:
# P down 1; Q down 1; O right 3; A left 2; Z up 4; R left 1; Q down 2; R left 1; B left 1; P down 2; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 0.44925808906555176 seconds
# Number of moves:  11
# Search path length: 187 states
# ------
# Solution path:
# P down 1; Q down 1; O right 3; A left 2; Z up 4; R left 1; Q down 2; R left 1; B left 1; P down 2; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 0.5277538299560547 seconds
# Number of moves:  11
# Search path length: 206 states
# ------
# Solution path:
# P down 1; Q down 1; A left 2; Z up 1; B left 1; O right 3; Z up 3; R left 2; P down 2; Q down 2; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 3.5544066429138184 seconds
# Number of moves:  9
# Search path length: 767 states
# ------
# Solution path:
# A left 2; Z up 2; R left 2; Q down 3; B left 1; P down 3; O right 3; Z up 2; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 3.5281238555908203 seconds
# Number of moves:  9
# Search path length: 767 states
# ------
# Solution path:
# A left 2; Z up 2; R left 2; Q down 3; B left 1; P down 3; O right 3; Z up 2; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 0.5188148021697998 seconds
# Number of moves:  9
# Search path length: 191 states
# ------
# Solution path:
# A left 2; Z up 3; R left 2; Q down 3; B left 1; P down 3; O right 3; Z up 1; A right 4; Initial board configuration
#
# OOO.PQ
# ....PQ
# ..AAPQ
# ......
# ..ZRRR
# ..ZBB.
#
# Car Fuel Available: O:10, P:10, Q:10, A:10, Z:4, R:100, B:1,
# Runtime: 2.049168109893799 seconds
# Number of moves:  9
# Search path length: 498 states
# ------
# Solution path:
# A left 2; Z up 2; R left 2; Q down 3; B left 1; P down 3; O right 3; Z up 2; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.0882868766784668 seconds
# Number of moves:  4
# Search path length: 84 states
# ------
# Solution path:
# Z left 1; B up 1; C up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.0106964111328125 seconds
# Number of moves:  4
# Search path length: 8 states
# ------
# Solution path:
# C up 1; Z left 1; B up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.011143922805786133 seconds
# Number of moves:  4
# Search path length: 8 states
# ------
# Solution path:
# C up 1; Z left 1; B up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.010688543319702148 seconds
# Number of moves:  4
# Search path length: 8 states
# ------
# Solution path:
# C up 1; Z left 1; B up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.012202978134155273 seconds
# Number of moves:  4
# Search path length: 8 states
# ------
# Solution path:
# Z left 1; B up 1; C up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.08597922325134277 seconds
# Number of moves:  4
# Search path length: 74 states
# ------
# Solution path:
# C up 1; Z left 1; B up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.0843658447265625 seconds
# Number of moves:  4
# Search path length: 74 states
# ------
# Solution path:
# C up 1; Z left 1; B up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.010625600814819336 seconds
# Number of moves:  4
# Search path length: 8 states
# ------
# Solution path:
# C up 1; Z left 1; B up 1; A right 4; Initial board configuration
#
# .ZZ...
# ..BC..
# AABC..
# .DD...
# ......
# ......
#
# Car Fuel Available: Z:2, B:2, C:2, A:100, D:2,
# Runtime: 0.07898545265197754 seconds
# Number of moves:  4
# Search path length: 65 states
# ------
# Solution path:
# Z left 1; B up 1; C up 1; A right 4; No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
# No Solution
